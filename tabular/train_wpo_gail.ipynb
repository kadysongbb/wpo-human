# %%
import gym
from datetime import datetime
import numpy as np
from scipy.stats import entropy

# DR TRPO related files
from train_helper import *
from value import NNValueFunction
from utils import Logger
from dr_policy import DRPolicyKL, DRPolicyWass, DRPolicySinkhorn

import tensorflow as tf
import tensorflow.contrib.distributions as dist
import tensorflow.contrib.layers as layers

# %% [markdown]
# ## Discriminator Network Setup

# %%
class Discriminator:
    def __init__(self, sess, hidden_size, lr, name):
        self.sess = sess
        self.hidden_size = hidden_size
        self.lr = lr
        self.name = name

        self.ob_ac = tf.placeholder(dtype=tf.float32, shape=[None, 2])
        
        with tf.variable_scope(name):
            self._build_network()

    def _build_network(self):
        with tf.variable_scope('discriminator'):
            d_h1 = layers.fully_connected(self.ob_ac, self.hidden_size, activation_fn=tf.tanh)
            d_h2 = layers.fully_connected(d_h1, self.hidden_size, activation_fn=tf.tanh)
            d_out = layers.fully_connected(d_h2, 1, activation_fn=None)

        self.reward = - tf.squeeze(tf.log(tf.sigmoid(d_out)))
        
        expert_out, policy_out = tf.split(d_out, num_or_size_splits=2, axis=0)

        self.loss = (tf.losses.sigmoid_cross_entropy(tf.ones_like(policy_out), policy_out)
                     + tf.losses.sigmoid_cross_entropy(tf.zeros_like(expert_out), expert_out))
        
        with tf.name_scope('train_op'):
            grads = tf.gradients(self.loss, self.params())
            self.grads = list(zip(grads, self.params()))
            self.train_op = tf.train.AdamOptimizer(self.lr).apply_gradients(self.grads)

    def params(self):
        return tf.global_variables(self.name).copy()

    def get_reward(self, expert_ob_ac):
        feed_dict = {self.ob_ac: expert_ob_ac}

        return self.sess.run(self.reward, feed_dict=feed_dict)

    def update(self, all_ob_ac):
        feed_dict = {self.ob_ac: all_ob_ac}

        self.sess.run(self.train_op, feed_dict=feed_dict)

# %% [markdown]
# # Discrete State Space - SPO + GAIL
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
config = tf.ConfigProto(
device_count={'GPU': 1},
intra_op_parallelism_threads=1,
allow_soft_placement=True
)
config.gpu_options.allow_growth = True
sess = tf.InteractiveSession(config=config)
tf.keras.backend.set_session(sess)
discriminator = Discriminator(sess, 10, 0.01, 'D')
sess.run(tf.global_variables_initializer())
tf.reset_default_graph()

env_name = 'Taxi-v3'
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicySinkhorn(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
gae_weight = 1
total_eps = 2000
batch_eps = 10
logger = Logger(logname=env_name + '_DR-Sinkhorn_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        # weight for RL
        lamb = 0.9
        # the randomness of the actions an agent takes can be quantified by the entropy
        entro = entropy(policy.distributions)
        trajectories = run_policy(env, policy, batch_eps, discriminator, lamb, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)
        # calculate advantage
        add_gae(trajectories, gamma, gae_weight)
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs, env_name, eps)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True)
        
        policy_ob_ac = np.stack((observes, actions),1)
        data = np.load('expert_traj/expert_taxi.npz')
        expert_obs = data['obs'].T[0]
        expert_actions = data['actions'].T[0]
        expert_ob_ac = np.stack((expert_obs, expert_actions),1)
        min_len = min(len(expert_ob_ac), len(policy_ob_ac))
        discriminator.update(np.concatenate([expert_ob_ac[:min_len], policy_ob_ac[:min_len]], axis=0))
logger.close()
sess.close()
# Out:
# /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 10, Mean Return = -694.6, Mean Discounted Return = -29.4 *****
# ExplainedVarNew: -3.72e-07
# ExplainedVarOld: -1.58e-08
# ValFuncLoss: 891
#
#
# ***** Episode 20, Mean Return = -605.9, Mean Discounted Return = -31.8 *****
# ExplainedVarNew: -1.38e-08
# ExplainedVarOld: -4.65e-07
# ValFuncLoss: 632
#
#
# ***** Episode 30, Mean Return = -634.7, Mean Discounted Return = -29.2 *****
# ExplainedVarNew: -8.1e-10
# ExplainedVarOld: -3.06e-09
# ValFuncLoss: 536
#
#
# ***** Episode 40, Mean Return = -645.8, Mean Discounted Return = -32.5 *****
# ExplainedVarNew: -8.61e-09
# ExplainedVarOld: -2.02e-08
# ValFuncLoss: 369
#
#
# ***** Episode 50, Mean Return = -572.3, Mean Discounted Return = -29.5 *****
# ExplainedVarNew: -1.5e-09
# ExplainedVarOld: -2.95e-09
# ValFuncLoss: 300
#
#
# ***** Episode 60, Mean Return = -512.0, Mean Discounted Return = -26.1 *****
# ExplainedVarNew: -4.13e-09
# ExplainedVarOld: -6.31e-09
# ValFuncLoss: 198
#
#
# ***** Episode 70, Mean Return = -522.9, Mean Discounted Return = -30.9 *****
# ExplainedVarNew: -1.65e-09
# ExplainedVarOld: -2.33e-09
# ValFuncLoss: 168
#
#
# ***** Episode 80, Mean Return = -513.3, Mean Discounted Return = -25.5 *****
# ExplainedVarNew: -5.18e-11
# ExplainedVarOld: -6.49e-11
# ValFuncLoss: 133
#
#
# ***** Episode 90, Mean Return = -600.8, Mean Discounted Return = -32.4 *****
# ExplainedVarNew: -2.08e-12
# ExplainedVarOld: -2.46e-12
# ValFuncLoss: 150
#
#
# ***** Episode 100, Mean Return = -487.1, Mean Discounted Return = -32.8 *****
# ExplainedVarNew: -7.77e-15
# ExplainedVarOld: -9.33e-15
# ValFuncLoss: 117
#
#
# ***** Episode 110, Mean Return = -460.7, Mean Discounted Return = -28.3 *****
# ExplainedVarNew: -1.02e-10
# ExplainedVarOld: -1.08e-10
# ValFuncLoss: 124
#
#
# ***** Episode 120, Mean Return = -439.1, Mean Discounted Return = -27.7 *****
# ExplainedVarNew: -1.34e-09
# ExplainedVarOld: -1.43e-09
# ValFuncLoss: 113
#
#
# ***** Episode 130, Mean Return = -508.1, Mean Discounted Return = -27.6 *****
# ExplainedVarNew: -1.7e-11
# ExplainedVarOld: -1.83e-11
# ValFuncLoss: 99.2
#
#
# ***** Episode 140, Mean Return = -556.3, Mean Discounted Return = -28.9 *****
# ExplainedVarNew: -1.57e-09
# ExplainedVarOld: -1.67e-09
# ValFuncLoss: 99
#
#
# ***** Episode 150, Mean Return = -399.2, Mean Discounted Return = -27.9 *****
# ExplainedVarNew: -3.13e-13
# ExplainedVarOld: -2.84e-13
# ValFuncLoss: 96.1
#
#
# ***** Episode 160, Mean Return = -501.2, Mean Discounted Return = -27.2 *****
# ExplainedVarNew: -6.78e-10
# ExplainedVarOld: -6.31e-10
# ValFuncLoss: 86.7
#
#
# ***** Episode 170, Mean Return = -409.7, Mean Discounted Return = -27.8 *****
# ExplainedVarNew: -1.04e-09
# ExplainedVarOld: -1.01e-09
# ValFuncLoss: 123
#
#
# ***** Episode 180, Mean Return = -374.2, Mean Discounted Return = -23.6 *****
# ExplainedVarNew: -7.77e-15
# ExplainedVarOld: -7.11e-15
# ValFuncLoss: 117
#
#
# ***** Episode 190, Mean Return = -414.6, Mean Discounted Return = -22.6 *****
# ExplainedVarNew: -1.56e-09
# ExplainedVarOld: -1.35e-09
# ValFuncLoss: 94
#
#
# ***** Episode 200, Mean Return = -358.9, Mean Discounted Return = -29.1 *****
# ExplainedVarNew: -1.37e-11
# ExplainedVarOld: -1.24e-11
# ValFuncLoss: 114
#
#
# ***** Episode 210, Mean Return = -328.6, Mean Discounted Return = -25.3 *****
# ExplainedVarNew: -3.48e-12
# ExplainedVarOld: -3.55e-12
# ValFuncLoss: 123
#
#
# ***** Episode 220, Mean Return = -428.9, Mean Discounted Return = -22.8 *****
# ExplainedVarNew: -7.95e-11
# ExplainedVarOld: -8e-11
# ValFuncLoss: 95.8
#
#
# ***** Episode 230, Mean Return = -350.2, Mean Discounted Return = -24.1 *****
# ExplainedVarNew: -4.42e-10
# ExplainedVarOld: -4.54e-10
# ValFuncLoss: 107
#
#
# ***** Episode 240, Mean Return = -374.2, Mean Discounted Return = -25.6 *****
# ExplainedVarNew: -1.28e-10
# ExplainedVarOld: -1.15e-10
# ValFuncLoss: 89.9
#
#
# ***** Episode 250, Mean Return = -326.4, Mean Discounted Return = -24.5 *****
# ExplainedVarNew: -1.26e-10
# ExplainedVarOld: -1.18e-10
# ValFuncLoss: 131
#
#
# ***** Episode 260, Mean Return = -329.3, Mean Discounted Return = -21.4 *****
# ExplainedVarNew: -1.07e-09
# ExplainedVarOld: -9.33e-10
# ValFuncLoss: 95.3
#
#
# ***** Episode 270, Mean Return = -379.8, Mean Discounted Return = -20.3 *****
# ExplainedVarNew: -1.42e-09
# ExplainedVarOld: -1.02e-09
# ValFuncLoss: 99.3
#
#
# ***** Episode 280, Mean Return = -352.4, Mean Discounted Return = -23.8 *****
# ExplainedVarNew: -2.63e-09
# ExplainedVarOld: -2.4e-09
# ValFuncLoss: 101
#
#
# ***** Episode 290, Mean Return = -270.4, Mean Discounted Return = -19.3 *****
# ExplainedVarNew: -9.2e-08
# ExplainedVarOld: -1.16e-08
# ValFuncLoss: 94.3
#
#
# ***** Episode 300, Mean Return = -282.5, Mean Discounted Return = -20.6 *****
# ExplainedVarNew: -0.00102
# ExplainedVarOld: -4.25e-10
# ValFuncLoss: 108
#
#
# ***** Episode 310, Mean Return = -322.0, Mean Discounted Return = -18.5 *****
# ExplainedVarNew: -0.00274
# ExplainedVarOld: -0.00235
# ValFuncLoss: 112
#
#
# ***** Episode 320, Mean Return = -243.4, Mean Discounted Return = -24.3 *****
# ExplainedVarNew: -2.91e-05
# ExplainedVarOld: -0.00233
# ValFuncLoss: 114
#
#
# ***** Episode 330, Mean Return = -324.6, Mean Discounted Return = -22.2 *****
# ExplainedVarNew: -9.07e-05
# ExplainedVarOld: -3.64e-07
# ValFuncLoss: 108
#
#
# ***** Episode 340, Mean Return = -213.8, Mean Discounted Return = -17.7 *****
# ExplainedVarNew: -0.00232
# ExplainedVarOld: -0.0123
# ValFuncLoss: 103
#
#
# ***** Episode 350, Mean Return = -262.8, Mean Discounted Return = -22.7 *****
# ExplainedVarNew: -0.000253
# ExplainedVarOld: -0.000201
# ValFuncLoss: 103
#
#
# ***** Episode 360, Mean Return = -347.1, Mean Discounted Return = -28.1 *****
# ExplainedVarNew: -0.00174
# ExplainedVarOld: -0.000318
# ValFuncLoss: 129
#
#
# ***** Episode 370, Mean Return = -256.1, Mean Discounted Return = -22.2 *****
# ExplainedVarNew: -0.00304
# ExplainedVarOld: -0.000375
# ValFuncLoss: 142
#
#
# ***** Episode 380, Mean Return = -267.1, Mean Discounted Return = -22.5 *****
# ExplainedVarNew: -2.07e-05
# ExplainedVarOld: -0.0261
# ValFuncLoss: 152
#
#
# ***** Episode 390, Mean Return = -204.2, Mean Discounted Return = -15.2 *****
# ExplainedVarNew: -1.65e-06
# ExplainedVarOld: -6.29e-07
# ValFuncLoss: 103
#
#
# ***** Episode 400, Mean Return = -244.5, Mean Discounted Return = -21.8 *****
# ExplainedVarNew: -9.1e-06
# ExplainedVarOld: -6.68e-06
# ValFuncLoss: 112
#
#
# ***** Episode 410, Mean Return = -247.2, Mean Discounted Return = -16.6 *****
# ExplainedVarNew: -3.64e-07
# ExplainedVarOld: -4.91e-07
# ValFuncLoss: 102
#
#
# ***** Episode 420, Mean Return = -228.4, Mean Discounted Return = -19.5 *****
# ExplainedVarNew: -5.18e-06
# ExplainedVarOld: -3.75e-06
# ValFuncLoss: 159
#
#
# ***** Episode 430, Mean Return = -264.0, Mean Discounted Return = -20.7 *****
# ExplainedVarNew: -3.44e-05
# ExplainedVarOld: -1.61e-05
# ValFuncLoss: 102
#
#
# ***** Episode 440, Mean Return = -151.3, Mean Discounted Return = -20.3 *****
# ExplainedVarNew: -0.000128
# ExplainedVarOld: -6.85e-05
# ValFuncLoss: 169
#
#
# ***** Episode 450, Mean Return = -231.4, Mean Discounted Return = -18.9 *****
# ExplainedVarNew: -2.05e-05
# ExplainedVarOld: -1.69e-05
# ValFuncLoss: 149
#
#
# ***** Episode 460, Mean Return = -193.7, Mean Discounted Return = -16.7 *****
# ExplainedVarNew: -3.25e-05
# ExplainedVarOld: -6.93e-05
# ValFuncLoss: 127
#
#
# ***** Episode 470, Mean Return = -312.2, Mean Discounted Return = -22.2 *****
# ExplainedVarNew: -1.8e-06
# ExplainedVarOld: -2.87e-06
# ValFuncLoss: 137
#
#
# ***** Episode 480, Mean Return = -204.9, Mean Discounted Return = -18.6 *****
# ExplainedVarNew: -2.26e-05
# ExplainedVarOld: -5.9e-06
# ValFuncLoss: 148
#
#
# ***** Episode 490, Mean Return = -238.8, Mean Discounted Return = -22.7 *****
# ExplainedVarNew: -0.000218
# ExplainedVarOld: -9.14e-06
# ValFuncLoss: 176
#
#
# ***** Episode 500, Mean Return = -127.6, Mean Discounted Return = -20.9 *****
# ExplainedVarNew: -0.000207
# ExplainedVarOld: -9.6e-05
# ValFuncLoss: 235
#
#
# ***** Episode 510, Mean Return = -155.8, Mean Discounted Return = -25.5 *****
# ExplainedVarNew: -0.00341
# ExplainedVarOld: -0.00176
# ValFuncLoss: 180
#
#
# ***** Episode 520, Mean Return = -114.5, Mean Discounted Return = -14.0 *****
# ExplainedVarNew: -0.00398
# ExplainedVarOld: -0.00113
# ValFuncLoss: 228
#
#
# ***** Episode 530, Mean Return = -158.2, Mean Discounted Return = -21.0 *****
# ExplainedVarNew: -0.00168
# ExplainedVarOld: -0.035
# ValFuncLoss: 180
#
#
# ***** Episode 540, Mean Return = -176.3, Mean Discounted Return = -22.6 *****
# ExplainedVarNew: -5.21e-05
# ExplainedVarOld: -0.00136
# ValFuncLoss: 182
#
#
# ***** Episode 550, Mean Return = -107.8, Mean Discounted Return = -21.2 *****
# ExplainedVarNew: -0.00155
# ExplainedVarOld: -0.000287
# ValFuncLoss: 155
# ***** Episode 560, Mean Return = -166.0, Mean Discounted Return = -20.3 *****
# ExplainedVarNew: -0.000263
# ExplainedVarOld: -0.000985
# ValFuncLoss: 215
#
#
# ***** Episode 570, Mean Return = -218.7, Mean Discounted Return = -19.3 *****
# ExplainedVarNew: -1.75e-05
# ExplainedVarOld: -0.00047
# ValFuncLoss: 166
#
#
# ***** Episode 580, Mean Return = -188.7, Mean Discounted Return = -23.3 *****
# ExplainedVarNew: -5.9e-05
# ExplainedVarOld: -4.32e-05
# ValFuncLoss: 164
#
#
# ***** Episode 590, Mean Return = -91.8, Mean Discounted Return = -17.5 *****
# ExplainedVarNew: -0.000338
# ExplainedVarOld: -6.65e-05
# ValFuncLoss: 198
#
#
# ***** Episode 600, Mean Return = -255.7, Mean Discounted Return = -25.5 *****
# ExplainedVarNew: -1.43e-05
# ExplainedVarOld: -0.000143
# ValFuncLoss: 145
#
#
# ***** Episode 610, Mean Return = -59.6, Mean Discounted Return = -21.3 *****
# ExplainedVarNew: -5.21e-06
# ExplainedVarOld: -6.66e-06
# ValFuncLoss: 281
#
#
# ***** Episode 620, Mean Return = -318.5, Mean Discounted Return = -25.6 *****
# ExplainedVarNew: -8.81e-06
# ExplainedVarOld: -2.13e-05
# ValFuncLoss: 152
#
#
# ***** Episode 630, Mean Return = -135.5, Mean Discounted Return = -20.9 *****
# ExplainedVarNew: -2.13e-06
# ExplainedVarOld: -1.91e-06
# ValFuncLoss: 232
#
#
# ***** Episode 640, Mean Return = -109.9, Mean Discounted Return = -24.0 *****
# ExplainedVarNew: -0.000117
# ExplainedVarOld: -9.89e-06
# ValFuncLoss: 239
#
#
# ***** Episode 650, Mean Return = -98.9, Mean Discounted Return = -21.7 *****
# ExplainedVarNew: -0.00132
# ExplainedVarOld: -0.000152
# ValFuncLoss: 191
#
#
# ***** Episode 660, Mean Return = -150.7, Mean Discounted Return = -24.9 *****
# ExplainedVarNew: -0.0427
# ExplainedVarOld: -0.00124
# ValFuncLoss: 195
#
#
# ***** Episode 670, Mean Return = -190.7, Mean Discounted Return = -27.3 *****
# ExplainedVarNew: -0.00264
# ExplainedVarOld: -0.039
# ValFuncLoss: 203
#
#
# ***** Episode 680, Mean Return = -161.9, Mean Discounted Return = -24.8 *****
# ExplainedVarNew: -0.00635
# ExplainedVarOld: -0.00944
# ValFuncLoss: 198
#
#
# ***** Episode 690, Mean Return = -106.7, Mean Discounted Return = -23.4 *****
# ExplainedVarNew: -0.0241
# ExplainedVarOld: -0.00747
# ValFuncLoss: 264
#
#
# ***** Episode 700, Mean Return = -193.5, Mean Discounted Return = -20.3 *****
# ExplainedVarNew: -0.000263
# ExplainedVarOld: -0.0896
# ValFuncLoss: 195
#
#
# ***** Episode 710, Mean Return = -185.7, Mean Discounted Return = -26.2 *****
# ExplainedVarNew: -1.64e-05
# ExplainedVarOld: -1.05e-05
# ValFuncLoss: 195
#
#
# ***** Episode 720, Mean Return = -164.7, Mean Discounted Return = -21.6 *****
# ExplainedVarNew: -0.000837
# ExplainedVarOld: -0.00131
# ValFuncLoss: 161
#
#
# ***** Episode 730, Mean Return = -185.2, Mean Discounted Return = -23.6 *****
# ExplainedVarNew: -0.000326
# ExplainedVarOld: -0.000236
# ValFuncLoss: 167
#
#
# ***** Episode 740, Mean Return = -262.6, Mean Discounted Return = -25.8 *****
# ExplainedVarNew: -3.02e-06
# ExplainedVarOld: -2.98e-06
# ValFuncLoss: 152
#
#
# ***** Episode 750, Mean Return = -170.8, Mean Discounted Return = -16.5 *****
# ExplainedVarNew: -2.08e-06
# ExplainedVarOld: -3.74e-06
# ValFuncLoss: 164
#
#
# ***** Episode 760, Mean Return = -107.0, Mean Discounted Return = -19.5 *****
# ExplainedVarNew: -0.01
# ExplainedVarOld: -0.000463
# ValFuncLoss: 233
#
#
# ***** Episode 770, Mean Return = -117.0, Mean Discounted Return = -22.5 *****
# ExplainedVarNew: -0.00925
# ExplainedVarOld: -0.00936
# ValFuncLoss: 231
#
#
# ***** Episode 780, Mean Return = -139.2, Mean Discounted Return = -16.2 *****
# ExplainedVarNew: -0.00624
# ExplainedVarOld: -0.00495
# ValFuncLoss: 200
#
#
# ***** Episode 790, Mean Return = -93.1, Mean Discounted Return = -19.7 *****
# ExplainedVarNew: -0.00437
# ExplainedVarOld: -0.004
# ValFuncLoss: 242
#
#
# ***** Episode 800, Mean Return = -115.9, Mean Discounted Return = -17.2 *****
# ExplainedVarNew: -0.00488
# ExplainedVarOld: -0.00896
# ValFuncLoss: 292
#
#
# ***** Episode 810, Mean Return = -133.4, Mean Discounted Return = -25.1 *****
# ExplainedVarNew: -0.00376
# ExplainedVarOld: -0.00247
# ValFuncLoss: 226
#
#
# ***** Episode 820, Mean Return = -276.0, Mean Discounted Return = -31.6 *****
# ExplainedVarNew: -4.28e-05
# ExplainedVarOld: -0.0636
# ValFuncLoss: 166
#
#
# ***** Episode 830, Mean Return = -130.7, Mean Discounted Return = -24.8 *****
# ExplainedVarNew: -3.14e-05
# ExplainedVarOld: -6.57e-05
# ValFuncLoss: 191
#
#
# ***** Episode 840, Mean Return = -95.6, Mean Discounted Return = -28.2 *****
# ExplainedVarNew: -8.74e-06
# ExplainedVarOld: -6.32e-06
# ValFuncLoss: 262
#
#
# ***** Episode 850, Mean Return = -166.2, Mean Discounted Return = -22.4 *****
# ExplainedVarNew: -1.32e-05
# ExplainedVarOld: -4.13e-06
# ValFuncLoss: 195
#
#
# ***** Episode 860, Mean Return = -147.9, Mean Discounted Return = -27.1 *****
# ExplainedVarNew: -0.00052
# ExplainedVarOld: -6.11e-05
# ValFuncLoss: 222
#
#
# ***** Episode 870, Mean Return = -125.2, Mean Discounted Return = -25.0 *****
# ExplainedVarNew: -0.00097
# ExplainedVarOld: -5.87e-05
# ValFuncLoss: 238
#
#
# ***** Episode 880, Mean Return = -230.4, Mean Discounted Return = -20.9 *****
# ExplainedVarNew: -0.00263
# ExplainedVarOld: -0.000978
# ValFuncLoss: 200
#
#
# ***** Episode 890, Mean Return = -163.8, Mean Discounted Return = -16.0 *****
# ExplainedVarNew: -2.6e-09
# ExplainedVarOld: -1.72e-09
# ValFuncLoss: 185
#
#
# ***** Episode 900, Mean Return = -145.2, Mean Discounted Return = -22.0 *****
# ExplainedVarNew: -0.00537
# ExplainedVarOld: -0.0294
# ValFuncLoss: 189
#
#
# ***** Episode 910, Mean Return = -97.8, Mean Discounted Return = -17.4 *****
# ExplainedVarNew: -0.00791
# ExplainedVarOld: -0.00369
# ValFuncLoss: 246
#
#
# ***** Episode 920, Mean Return = -124.2, Mean Discounted Return = -26.8 *****
# ExplainedVarNew: -0.0109
# ExplainedVarOld: -0.00636
# ValFuncLoss: 217
#
#
# ***** Episode 930, Mean Return = -182.3, Mean Discounted Return = -22.8 *****
# ExplainedVarNew: -0.00234
# ExplainedVarOld: -0.00186
# ValFuncLoss: 196
#
#
# ***** Episode 940, Mean Return = -196.9, Mean Discounted Return = -24.9 *****
# ExplainedVarNew: -0.0138
# ExplainedVarOld: -0.00404
# ValFuncLoss: 210
#
#
# ***** Episode 950, Mean Return = -180.1, Mean Discounted Return = -21.5 *****
# ExplainedVarNew: -0.00196
# ExplainedVarOld: -0.00186
# ValFuncLoss: 180
#
#
# ***** Episode 960, Mean Return = -108.0, Mean Discounted Return = -22.7 *****
# ExplainedVarNew: -0.0141
# ExplainedVarOld: -0.0168
# ValFuncLoss: 240
#
#
# ***** Episode 970, Mean Return = -128.0, Mean Discounted Return = -27.9 *****
# ExplainedVarNew: -0.00743
# ExplainedVarOld: -0.00857
# ValFuncLoss: 290
#
#
# ***** Episode 980, Mean Return = -79.2, Mean Discounted Return = -24.7 *****
# ExplainedVarNew: -0.0108
# ExplainedVarOld: -0.0231
# ValFuncLoss: 275
#
#
# ***** Episode 990, Mean Return = -295.8, Mean Discounted Return = -26.5 *****
# ExplainedVarNew: -0.00152
# ExplainedVarOld: -0.000178
# ValFuncLoss: 218
#
#
# ***** Episode 1000, Mean Return = -97.5, Mean Discounted Return = -23.6 *****
# ExplainedVarNew: -0.0175
# ExplainedVarOld: -0.0163
# ValFuncLoss: 272
#
#
# ***** Episode 1010, Mean Return = -138.0, Mean Discounted Return = -15.6 *****
# ExplainedVarNew: -0.000869
# ExplainedVarOld: -0.0013
# ValFuncLoss: 271
#
#
# ***** Episode 1020, Mean Return = -150.0, Mean Discounted Return = -16.9 *****
# ExplainedVarNew: -0.00307
# ExplainedVarOld: -0.00188
# ValFuncLoss: 196
#
#
# ***** Episode 1030, Mean Return = -171.8, Mean Discounted Return = -24.4 *****
# ExplainedVarNew: -0.00897
# ExplainedVarOld: -0.00447
# ValFuncLoss: 236
#
#
# ***** Episode 1040, Mean Return = -79.5, Mean Discounted Return = -21.4 *****
# ExplainedVarNew: -0.0165
# ExplainedVarOld: -0.0146
# ValFuncLoss: 331
#
#
# ***** Episode 1050, Mean Return = -133.8, Mean Discounted Return = -20.4 *****
# ExplainedVarNew: -0.00836
# ExplainedVarOld: -0.0156
# ValFuncLoss: 243
#
#
# ***** Episode 1060, Mean Return = -145.9, Mean Discounted Return = -22.8 *****
# ExplainedVarNew: -0.00672
# ExplainedVarOld: -0.00697
# ValFuncLoss: 283
#
#
# ***** Episode 1070, Mean Return = -94.5, Mean Discounted Return = -21.6 *****
# ExplainedVarNew: -0.00796
# ExplainedVarOld: -0.00804
# ValFuncLoss: 230
#
#
# ***** Episode 1080, Mean Return = -151.9, Mean Discounted Return = -22.8 *****
# ExplainedVarNew: -0.00728
# ExplainedVarOld: -0.00751
# ValFuncLoss: 228
#
#
# ***** Episode 1090, Mean Return = -155.9, Mean Discounted Return = -25.9 *****
# ExplainedVarNew: -0.00462
# ExplainedVarOld: -0.00304
# ValFuncLoss: 306
#
#
# ***** Episode 1100, Mean Return = -263.0, Mean Discounted Return = -24.3 *****
# ExplainedVarNew: -0.00516
# ExplainedVarOld: -0.00219
# ValFuncLoss: 215
#
#
# ***** Episode 1110, Mean Return = -162.8, Mean Discounted Return = -28.2 *****
# ExplainedVarNew: -0.00776
# ExplainedVarOld: -0.036
# ValFuncLoss: 259
# ***** Episode 1120, Mean Return = -206.9, Mean Discounted Return = -20.6 *****
# ExplainedVarNew: -0.0096
# ExplainedVarOld: -0.00741
# ValFuncLoss: 243
#
#
# ***** Episode 1130, Mean Return = -119.8, Mean Discounted Return = -19.3 *****
# ExplainedVarNew: -0.0118
# ExplainedVarOld: -0.00928
# ValFuncLoss: 240
#
#
# ***** Episode 1140, Mean Return = -152.7, Mean Discounted Return = -25.7 *****
# ExplainedVarNew: -0.0175
# ExplainedVarOld: -0.0496
# ValFuncLoss: 213
#
#
# ***** Episode 1150, Mean Return = -132.5, Mean Discounted Return = -25.3 *****
# ExplainedVarNew: -0.00353
# ExplainedVarOld: -0.00238
# ValFuncLoss: 223
#
#
# ***** Episode 1160, Mean Return = -105.5, Mean Discounted Return = -20.7 *****
# ExplainedVarNew: -0.00222
# ExplainedVarOld: -0.002
# ValFuncLoss: 265
#
#
# ***** Episode 1170, Mean Return = -202.8, Mean Discounted Return = -19.3 *****
# ExplainedVarNew: -0.0154
# ExplainedVarOld: -0.0212
# ValFuncLoss: 195
#
#
# ***** Episode 1180, Mean Return = -331.8, Mean Discounted Return = -24.9 *****
# ExplainedVarNew: -0.0032
# ExplainedVarOld: -0.00406
# ValFuncLoss: 168
#
#
# ***** Episode 1190, Mean Return = -126.9, Mean Discounted Return = -22.0 *****
# ExplainedVarNew: -0.0133
# ExplainedVarOld: -0.014
# ValFuncLoss: 228
#
#
# ***** Episode 1200, Mean Return = -75.2, Mean Discounted Return = -24.6 *****
# ExplainedVarNew: -0.00116
# ExplainedVarOld: -0.0019
# ValFuncLoss: 286
#
#
# ***** Episode 1210, Mean Return = -142.2, Mean Discounted Return = -24.6 *****
# ExplainedVarNew: -0.012
# ExplainedVarOld: -0.00576
# ValFuncLoss: 235
#
#
# ***** Episode 1220, Mean Return = -149.9, Mean Discounted Return = -25.9 *****
# ExplainedVarNew: -0.0015
# ExplainedVarOld: -0.00161
# ValFuncLoss: 257
#
#
# ***** Episode 1230, Mean Return = -80.3, Mean Discounted Return = -22.7 *****
# ExplainedVarNew: -1.82e-07
# ExplainedVarOld: -2.47e-07
# ValFuncLoss: 330
#
#
# ***** Episode 1240, Mean Return = -131.3, Mean Discounted Return = -21.1 *****
# ExplainedVarNew: -0.00325
# ExplainedVarOld: -0.00302
# ValFuncLoss: 268
#
#
# ***** Episode 1250, Mean Return = -154.9, Mean Discounted Return = -23.5 *****
# ExplainedVarNew: -0.0202
# ExplainedVarOld: -0.0207
# ValFuncLoss: 199
#
#
# ***** Episode 1260, Mean Return = -168.9, Mean Discounted Return = -30.6 *****
# ExplainedVarNew: -0.00429
# ExplainedVarOld: -0.00394
# ValFuncLoss: 264
#
#
# ***** Episode 1270, Mean Return = -123.6, Mean Discounted Return = -21.5 *****
# ExplainedVarNew: -3.42e-09
# ExplainedVarOld: -0.0273
# ValFuncLoss: 278
#
#
# ***** Episode 1280, Mean Return = -166.0, Mean Discounted Return = -26.3 *****
# ExplainedVarNew: -5.7e-06
# ExplainedVarOld: -2.63e-06
# ValFuncLoss: 206
#
#
# ***** Episode 1290, Mean Return = -231.5, Mean Discounted Return = -29.1 *****
# ExplainedVarNew: -0.000274
# ExplainedVarOld: -6.63e-07
# ValFuncLoss: 251
#
#
# ***** Episode 1300, Mean Return = -236.4, Mean Discounted Return = -26.0 *****
# ExplainedVarNew: -0.000527
# ExplainedVarOld: -1.13e-09
# ValFuncLoss: 246
#
#
# ***** Episode 1310, Mean Return = -132.1, Mean Discounted Return = -18.1 *****
# ExplainedVarNew: -0.00106
# ExplainedVarOld: -0.000968
# ValFuncLoss: 301
#
#
# ***** Episode 1320, Mean Return = -191.0, Mean Discounted Return = -22.9 *****
# ExplainedVarNew: -0.00669
# ExplainedVarOld: -0.00555
# ValFuncLoss: 291
#
#
# ***** Episode 1330, Mean Return = -193.8, Mean Discounted Return = -20.2 *****
# ExplainedVarNew: -0.0212
# ExplainedVarOld: -0.0146
# ValFuncLoss: 229
#
#
# ***** Episode 1340, Mean Return = -155.9, Mean Discounted Return = -22.8 *****
# ExplainedVarNew: -0.0123
# ExplainedVarOld: -0.00976
# ValFuncLoss: 216
#
#
# ***** Episode 1350, Mean Return = -90.9, Mean Discounted Return = -17.1 *****
# ExplainedVarNew: -0.0119
# ExplainedVarOld: -0.0128
# ValFuncLoss: 310
#
#
# ***** Episode 1360, Mean Return = -112.9, Mean Discounted Return = -21.8 *****
# ExplainedVarNew: -0.0185
# ExplainedVarOld: -0.0231
# ValFuncLoss: 257
#
#
# ***** Episode 1370, Mean Return = -101.2, Mean Discounted Return = -25.6 *****
# ExplainedVarNew: -0.0126
# ExplainedVarOld: -0.0107
# ValFuncLoss: 254
#
#
# ***** Episode 1380, Mean Return = -173.2, Mean Discounted Return = -20.6 *****
# ExplainedVarNew: -0.0102
# ExplainedVarOld: -0.0089
# ValFuncLoss: 259
#
#
# ***** Episode 1390, Mean Return = -90.5, Mean Discounted Return = -22.2 *****
# ExplainedVarNew: -0.019
# ExplainedVarOld: -0.0684
# ValFuncLoss: 219
#
#
# ***** Episode 1400, Mean Return = -185.2, Mean Discounted Return = -27.5 *****
# ExplainedVarNew: -0.000475
# ExplainedVarOld: -0.000922
# ValFuncLoss: 232
#
#
# ***** Episode 1410, Mean Return = -173.0, Mean Discounted Return = -18.1 *****
# ExplainedVarNew: -0.00732
# ExplainedVarOld: -0.0045
# ValFuncLoss: 236
#
#
# ***** Episode 1420, Mean Return = -258.3, Mean Discounted Return = -35.4 *****
# ExplainedVarNew: -0.00796
# ExplainedVarOld: -0.00356
# ValFuncLoss: 221
#
#
# ***** Episode 1430, Mean Return = -113.5, Mean Discounted Return = -24.7 *****
# ExplainedVarNew: -0.0114
# ExplainedVarOld: -0.0164
# ValFuncLoss: 302
#
#
# ***** Episode 1440, Mean Return = -57.3, Mean Discounted Return = -23.3 *****
# ExplainedVarNew: -0.00153
# ExplainedVarOld: -5.6e-11
# ValFuncLoss: 332
#
#
# ***** Episode 1450, Mean Return = -306.1, Mean Discounted Return = -25.6 *****
# ExplainedVarNew: -4.43e-10
# ExplainedVarOld: -0.00508
# ValFuncLoss: 177
#
#
# ***** Episode 1460, Mean Return = -68.0, Mean Discounted Return = -24.8 *****
# ExplainedVarNew: -1.04e-08
# ExplainedVarOld: -1.01e-08
# ValFuncLoss: 380
#
#
# ***** Episode 1470, Mean Return = -161.9, Mean Discounted Return = -23.4 *****
# ExplainedVarNew: -0.0135
# ExplainedVarOld: -0.000321
# ValFuncLoss: 228
#
#
# ***** Episode 1480, Mean Return = -26.4, Mean Discounted Return = -17.0 *****
# ExplainedVarNew: -3.22e-11
# ExplainedVarOld: -3.09e-11
# ValFuncLoss: 453
#
#
# ***** Episode 1490, Mean Return = -171.5, Mean Discounted Return = -23.6 *****
# ExplainedVarNew: -0.000671
# ExplainedVarOld: -0.000922
# ValFuncLoss: 268
#
#
# ***** Episode 1500, Mean Return = -282.5, Mean Discounted Return = -29.2 *****
# ExplainedVarNew: -0.00055
# ExplainedVarOld: -8e-05
# ValFuncLoss: 190
#
#
# ***** Episode 1510, Mean Return = -247.2, Mean Discounted Return = -29.6 *****
# ExplainedVarNew: -5.45e-11
# ExplainedVarOld: -6.02e-11
# ValFuncLoss: 181
#
#
# ***** Episode 1520, Mean Return = -111.2, Mean Discounted Return = -22.6 *****
# ExplainedVarNew: -0.00977
# ExplainedVarOld: -0.0367
# ValFuncLoss: 328
#
#
# ***** Episode 1530, Mean Return = -169.6, Mean Discounted Return = -24.5 *****
# ExplainedVarNew: -0.0157
# ExplainedVarOld: -0.00567
# ValFuncLoss: 260
#
#
# ***** Episode 1540, Mean Return = -76.1, Mean Discounted Return = -17.0 *****
# ExplainedVarNew: -0.00268
# ExplainedVarOld: -0.00112
# ValFuncLoss: 370
#
#
# ***** Episode 1550, Mean Return = -150.7, Mean Discounted Return = -21.3 *****
# ExplainedVarNew: -0.00796
# ExplainedVarOld: -0.0152
# ValFuncLoss: 233
#
#
# ***** Episode 1560, Mean Return = -131.2, Mean Discounted Return = -21.6 *****
# ExplainedVarNew: -0.00801
# ExplainedVarOld: -0.0261
# ValFuncLoss: 235
#
#
# ***** Episode 1570, Mean Return = -144.6, Mean Discounted Return = -26.8 *****
# ExplainedVarNew: -0.00296
# ExplainedVarOld: -0.00272
# ValFuncLoss: 295
#
#
# ***** Episode 1580, Mean Return = -205.9, Mean Discounted Return = -18.5 *****
# ExplainedVarNew: -0.00618
# ExplainedVarOld: -0.00377
# ValFuncLoss: 227
#
#
# ***** Episode 1590, Mean Return = -148.3, Mean Discounted Return = -25.2 *****
# ExplainedVarNew: -0.00452
# ExplainedVarOld: -0.00351
# ValFuncLoss: 234
#
#
# ***** Episode 1600, Mean Return = -140.8, Mean Discounted Return = -27.5 *****
# ExplainedVarNew: -0.0103
# ExplainedVarOld: -0.00617
# ValFuncLoss: 295
#
#
# ***** Episode 1610, Mean Return = -115.2, Mean Discounted Return = -16.8 *****
# ExplainedVarNew: -0.0194
# ExplainedVarOld: -0.0186
# ValFuncLoss: 299
#
#
# ***** Episode 1620, Mean Return = -117.8, Mean Discounted Return = -23.2 *****
# ExplainedVarNew: -1.98e-09
# ExplainedVarOld: -1e-08
# ValFuncLoss: 292
#
#
# ***** Episode 1630, Mean Return = -249.5, Mean Discounted Return = -23.2 *****
# ExplainedVarNew: -0.013
# ExplainedVarOld: -0.0141
# ValFuncLoss: 189
#
#
# ***** Episode 1640, Mean Return = -173.5, Mean Discounted Return = -24.6 *****
# ExplainedVarNew: -0.00318
# ExplainedVarOld: -0.00407
# ValFuncLoss: 214
#
#
# ***** Episode 1650, Mean Return = -228.3, Mean Discounted Return = -25.0 *****
# ExplainedVarNew: -0.021
# ExplainedVarOld: -0.0142
# ValFuncLoss: 258
#
#
# ***** Episode 1660, Mean Return = -281.7, Mean Discounted Return = -24.3 *****
# ExplainedVarNew: -0.0135
# ExplainedVarOld: -0.0102
# ValFuncLoss: 192
#
#
# ***** Episode 1670, Mean Return = -90.6, Mean Discounted Return = -20.8 *****
# ExplainedVarNew: -5.91e-11
# ExplainedVarOld: -6.21e-11
# ValFuncLoss: 296
# ***** Episode 1680, Mean Return = -73.2, Mean Discounted Return = -22.0 *****
# ExplainedVarNew: -0.0179
# ExplainedVarOld: -0.0375
# ValFuncLoss: 358
#
#
# ***** Episode 1690, Mean Return = -268.5, Mean Discounted Return = -30.5 *****
# ExplainedVarNew: -1.05e-10
# ExplainedVarOld: -9.54e-11
# ValFuncLoss: 240
#
#
# ***** Episode 1700, Mean Return = -255.0, Mean Discounted Return = -20.9 *****
# ExplainedVarNew: -6.27e-11
# ExplainedVarOld: -7.3e-11
# ValFuncLoss: 163
#
#
# ***** Episode 1710, Mean Return = -157.0, Mean Discounted Return = -26.5 *****
# ExplainedVarNew: -0.0147
# ExplainedVarOld: -0.027
# ValFuncLoss: 242
#
#
# ***** Episode 1720, Mean Return = -88.4, Mean Discounted Return = -18.5 *****
# ExplainedVarNew: -0.00788
# ExplainedVarOld: -0.0066
# ValFuncLoss: 270
#
#
# ***** Episode 1730, Mean Return = -192.4, Mean Discounted Return = -22.7 *****
# ExplainedVarNew: -0.0118
# ExplainedVarOld: -0.00666
# ValFuncLoss: 251
#
#
# ***** Episode 1740, Mean Return = -256.5, Mean Discounted Return = -28.7 *****
# ExplainedVarNew: -0.00511
# ExplainedVarOld: -0.00539
# ValFuncLoss: 224
#
#
# ***** Episode 1750, Mean Return = -126.8, Mean Discounted Return = -19.6 *****
# ExplainedVarNew: -0.0177
# ExplainedVarOld: -0.0182
# ValFuncLoss: 238
#
#
# ***** Episode 1760, Mean Return = -130.9, Mean Discounted Return = -23.4 *****
# ExplainedVarNew: -0.0155
# ExplainedVarOld: -0.0385
# ValFuncLoss: 268
#
#
# ***** Episode 1770, Mean Return = -109.0, Mean Discounted Return = -23.9 *****
# ExplainedVarNew: -0.00663
# ExplainedVarOld: -0.0149
# ValFuncLoss: 363
#
#
# ***** Episode 1780, Mean Return = -87.0, Mean Discounted Return = -19.2 *****
# ExplainedVarNew: -0.0115
# ExplainedVarOld: -0.00269
# ValFuncLoss: 290
#
#
# ***** Episode 1790, Mean Return = -135.8, Mean Discounted Return = -27.4 *****
# ExplainedVarNew: -0.00075
# ExplainedVarOld: -0.000695
# ValFuncLoss: 328
#
#
# ***** Episode 1800, Mean Return = -192.2, Mean Discounted Return = -25.7 *****
# ExplainedVarNew: -0.00802
# ExplainedVarOld: -0.00624
# ValFuncLoss: 230
#
#
# ***** Episode 1810, Mean Return = -151.4, Mean Discounted Return = -31.6 *****
# ExplainedVarNew: -3.17e-07
# ExplainedVarOld: -3.5e-06
# ValFuncLoss: 291
#
#
# ***** Episode 1820, Mean Return = -149.5, Mean Discounted Return = -25.0 *****
# ExplainedVarNew: -0.00807
# ExplainedVarOld: -0.00518
# ValFuncLoss: 231
#
#
# ***** Episode 1830, Mean Return = -177.5, Mean Discounted Return = -26.6 *****
# ExplainedVarNew: -0.00145
# ExplainedVarOld: -0.00149
# ValFuncLoss: 222
#
#
# ***** Episode 1840, Mean Return = -97.4, Mean Discounted Return = -18.5 *****
# ExplainedVarNew: -4.42e-11
# ExplainedVarOld: -4.05e-11
# ValFuncLoss: 301
#
#
# ***** Episode 1850, Mean Return = -90.8, Mean Discounted Return = -17.5 *****
# ExplainedVarNew: -0.0215
# ExplainedVarOld: -0.0194
# ValFuncLoss: 284
#
#
# ***** Episode 1860, Mean Return = -96.4, Mean Discounted Return = -16.1 *****
# ExplainedVarNew: -0.0209
# ExplainedVarOld: -0.0348
# ValFuncLoss: 288
#
#
# ***** Episode 1870, Mean Return = -151.7, Mean Discounted Return = -26.7 *****
# ExplainedVarNew: -0.0149
# ExplainedVarOld: -0.0108
# ValFuncLoss: 292
#
#
# ***** Episode 1880, Mean Return = -134.6, Mean Discounted Return = -27.6 *****
# ExplainedVarNew: -0.00135
# ExplainedVarOld: -0.00086
# ValFuncLoss: 237
#
#
# ***** Episode 1890, Mean Return = -96.9, Mean Discounted Return = -21.8 *****
# ExplainedVarNew: -0.0046
# ExplainedVarOld: -0.00298
# ValFuncLoss: 284
#
#
# ***** Episode 1900, Mean Return = -74.8, Mean Discounted Return = -20.5 *****
# ExplainedVarNew: -0.021
# ExplainedVarOld: -0.0214
# ValFuncLoss: 354
#
#
# ***** Episode 1910, Mean Return = -192.3, Mean Discounted Return = -27.1 *****
# ExplainedVarNew: -0.00263
# ExplainedVarOld: -0.00329
# ValFuncLoss: 203
#
#
# ***** Episode 1920, Mean Return = -179.7, Mean Discounted Return = -30.9 *****
# ExplainedVarNew: -0.00754
# ExplainedVarOld: -0.0198
# ValFuncLoss: 280
#
#
# ***** Episode 1930, Mean Return = -157.8, Mean Discounted Return = -22.4 *****
# ExplainedVarNew: -5.45e-10
# ExplainedVarOld: -6.46e-10
# ValFuncLoss: 197
#
#
# ***** Episode 1940, Mean Return = -149.7, Mean Discounted Return = -20.9 *****
# ExplainedVarNew: -0.0151
# ExplainedVarOld: -0.00835
# ValFuncLoss: 212
#
#
# ***** Episode 1950, Mean Return = -185.1, Mean Discounted Return = -25.8 *****
# ExplainedVarNew: -0.0207
# ExplainedVarOld: -0.0263
# ValFuncLoss: 293
#
#
# ***** Episode 1960, Mean Return = -139.0, Mean Discounted Return = -20.2 *****
# ExplainedVarNew: -0.0247
# ExplainedVarOld: -0.0342
# ValFuncLoss: 230
#
#
# ***** Episode 1970, Mean Return = -145.3, Mean Discounted Return = -20.1 *****
# ExplainedVarNew: -0.00212
# ExplainedVarOld: -0.00818
# ValFuncLoss: 259
#
#
# ***** Episode 1980, Mean Return = -142.4, Mean Discounted Return = -21.4 *****
# ExplainedVarNew: -0.00841
# ExplainedVarOld: -0.0132
# ValFuncLoss: 219
#
#
# ***** Episode 1990, Mean Return = -165.4, Mean Discounted Return = -26.8 *****
# ExplainedVarNew: -0.013
# ExplainedVarOld: -0.00583
# ValFuncLoss: 262
#
#
# ***** Episode 2000, Mean Return = -129.5, Mean Discounted Return = -25.6 *****
# ExplainedVarNew: -0.0104
# ExplainedVarOld: -0.02
# ValFuncLoss: 238

# %% [markdown]
# # Discrete State Space - WPO + GAIL
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
config = tf.ConfigProto(
device_count={'GPU': 1},
intra_op_parallelism_threads=1,
allow_soft_placement=True
)
config.gpu_options.allow_growth = True
sess = tf.InteractiveSession(config=config)
tf.keras.backend.set_session(sess)
discriminator = Discriminator(sess, 10, 0.01, 'D')
sess.run(tf.global_variables_initializer())
tf.reset_default_graph()

env_name = 'Taxi-v3'
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyWass(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
gae_weight = 1
total_eps = 2000
batch_eps = 10
logger = Logger(logname=env_name + '_DR-Wass_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        # weight for RL
        lamb = 0.9
        # the randomness of the actions an agent takes can be quantified by the entropy
        entro = entropy(policy.distributions)
        trajectories = run_policy(env, policy, batch_eps, discriminator, lamb, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, gae_weight)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs, env_name, eps)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True)
        
        policy_ob_ac = np.stack((observes, actions),1)
        data = np.load('expert_traj/expert_taxi.npz')
        expert_obs = data['obs'].T[0]
        expert_actions = data['actions'].T[0]
        expert_ob_ac = np.stack((expert_obs, expert_actions),1)
        min_len = min(len(expert_ob_ac), len(policy_ob_ac))
        discriminator.update(np.concatenate([expert_ob_ac[:min_len], policy_ob_ac[:min_len]], axis=0))
logger.close()
sess.close()
# Out:
# /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 10, Mean Return = -692.2, Mean Discounted Return = -35.5 *****
# ExplainedVarNew: -6.86e-08
# ExplainedVarOld: -2.76e-05
# ValFuncLoss: 931
#
#
# ***** Episode 20, Mean Return = -686.0, Mean Discounted Return = -34.7 *****
# ExplainedVarNew: -6.72e-11
# ExplainedVarOld: -1.05e-09
# ValFuncLoss: 746
#
#
# ***** Episode 30, Mean Return = -616.6, Mean Discounted Return = -25.1 *****
# ExplainedVarNew: -9.79e-12
# ExplainedVarOld: -2.71e-11
# ValFuncLoss: 496
#
#
# ***** Episode 40, Mean Return = -574.6, Mean Discounted Return = -30.2 *****
# ExplainedVarNew: -4.8e-10
# ExplainedVarOld: -1.01e-09
# ValFuncLoss: 294
#
#
# ***** Episode 50, Mean Return = -575.3, Mean Discounted Return = -34.6 *****
# ExplainedVarNew: -4.58e-11
# ExplainedVarOld: -7.23e-11
# ValFuncLoss: 305
#
#
# ***** Episode 60, Mean Return = -501.0, Mean Discounted Return = -30.1 *****
# ExplainedVarNew: -1.02e-12
# ExplainedVarOld: -1.28e-12
# ValFuncLoss: 204
#
#
# ***** Episode 70, Mean Return = -593.6, Mean Discounted Return = -32.8 *****
# ExplainedVarNew: -2.16e-11
# ExplainedVarOld: -2.8e-11
# ValFuncLoss: 237
#
#
# ***** Episode 80, Mean Return = -476.0, Mean Discounted Return = -27.2 *****
# ExplainedVarNew: -2.31e-12
# ExplainedVarOld: -2.87e-12
# ValFuncLoss: 155
#
#
# ***** Episode 90, Mean Return = -447.2, Mean Discounted Return = -25.3 *****
# ExplainedVarNew: -3.84e-14
# ExplainedVarOld: -5.64e-14
# ValFuncLoss: 151
#
#
# ***** Episode 100, Mean Return = -443.6, Mean Discounted Return = -28.2 *****
# ExplainedVarNew: -3.21e-13
# ExplainedVarOld: -3.57e-13
# ValFuncLoss: 172
#
#
# ***** Episode 110, Mean Return = -512.1, Mean Discounted Return = -31.6 *****
# ExplainedVarNew: -3.32e-13
# ExplainedVarOld: -3.68e-13
# ValFuncLoss: 168
#
#
# ***** Episode 120, Mean Return = -397.2, Mean Discounted Return = -31.5 *****
# ExplainedVarNew: -2.91e-11
# ExplainedVarOld: -2.58e-11
# ValFuncLoss: 133
#
#
# ***** Episode 130, Mean Return = -386.6, Mean Discounted Return = -26.1 *****
# ExplainedVarNew: -1.57e-13
# ExplainedVarOld: -1.27e-13
# ValFuncLoss: 143
#
#
# ***** Episode 140, Mean Return = -404.9, Mean Discounted Return = -26.4 *****
# ExplainedVarNew: -7.93e-14
# ExplainedVarOld: -8.73e-14
# ValFuncLoss: 148
#
#
# ***** Episode 150, Mean Return = -385.4, Mean Discounted Return = -26.9 *****
# ExplainedVarNew: -4.48e-13
# ExplainedVarOld: -4.21e-13
# ValFuncLoss: 159
#
#
# ***** Episode 160, Mean Return = -368.2, Mean Discounted Return = -25.4 *****
# ExplainedVarNew: -5.45e-11
# ExplainedVarOld: -4.44e-11
# ValFuncLoss: 134
#
#
# ***** Episode 170, Mean Return = -526.3, Mean Discounted Return = -29.9 *****
# ExplainedVarNew: -8.62e-13
# ExplainedVarOld: -9.24e-13
# ValFuncLoss: 128
#
#
# ***** Episode 180, Mean Return = -371.7, Mean Discounted Return = -29.7 *****
# ExplainedVarNew: -1.7e-10
# ExplainedVarOld: -8.78e-11
# ValFuncLoss: 135
#
#
# ***** Episode 190, Mean Return = -453.4, Mean Discounted Return = -25.5 *****
# ExplainedVarNew: -2.07e-11
# ExplainedVarOld: -9.54e-13
# ValFuncLoss: 173
#
#
# ***** Episode 200, Mean Return = -475.0, Mean Discounted Return = -29.3 *****
# ExplainedVarNew: -3.49e-09
# ExplainedVarOld: -3.32e-09
# ValFuncLoss: 120
#
#
# ***** Episode 210, Mean Return = -378.3, Mean Discounted Return = -27.6 *****
# ExplainedVarNew: -4.7e-11
# ExplainedVarOld: -3.94e-11
# ValFuncLoss: 105
#
#
# ***** Episode 220, Mean Return = -473.0, Mean Discounted Return = -23.8 *****
# ExplainedVarNew: -1.91e-08
# ExplainedVarOld: -5.74e-09
# ValFuncLoss: 128
#
#
# ***** Episode 230, Mean Return = -373.2, Mean Discounted Return = -17.9 *****
# ExplainedVarNew: -2.75e-09
# ExplainedVarOld: -5.44e-14
# ValFuncLoss: 94.8
#
#
# ***** Episode 240, Mean Return = -326.0, Mean Discounted Return = -22.4 *****
# ExplainedVarNew: -0.00163
# ExplainedVarOld: -0.0329
# ValFuncLoss: 93.7
#
#
# ***** Episode 250, Mean Return = -294.3, Mean Discounted Return = -21.4 *****
# ExplainedVarNew: -0.000111
# ExplainedVarOld: -0.00129
# ValFuncLoss: 80.6
#
#
# ***** Episode 260, Mean Return = -292.5, Mean Discounted Return = -20.6 *****
# ExplainedVarNew: -4.38e-05
# ExplainedVarOld: -0.000116
# ValFuncLoss: 102
#
#
# ***** Episode 270, Mean Return = -353.2, Mean Discounted Return = -18.7 *****
# ExplainedVarNew: -8.23e-05
# ExplainedVarOld: -0.000114
# ValFuncLoss: 83.7
#
#
# ***** Episode 280, Mean Return = -324.2, Mean Discounted Return = -22.3 *****
# ExplainedVarNew: -0.061
# ExplainedVarOld: -0.00224
# ValFuncLoss: 88.4
#
#
# ***** Episode 290, Mean Return = -307.2, Mean Discounted Return = -25.0 *****
# ExplainedVarNew: -0.00619
# ExplainedVarOld: -0.00942
# ValFuncLoss: 58.9
#
#
# ***** Episode 300, Mean Return = -339.8, Mean Discounted Return = -20.1 *****
# ExplainedVarNew: -0.0339
# ExplainedVarOld: -0.0294
# ValFuncLoss: 79.7
#
#
# ***** Episode 310, Mean Return = -314.6, Mean Discounted Return = -17.0 *****
# ExplainedVarNew: -0.0607
# ExplainedVarOld: -0.0424
# ValFuncLoss: 95.6
#
#
# ***** Episode 320, Mean Return = -431.8, Mean Discounted Return = -25.5 *****
# ExplainedVarNew: -0.000193
# ExplainedVarOld: -0.000161
# ValFuncLoss: 599
#
#
# ***** Episode 330, Mean Return = -238.7, Mean Discounted Return = -16.0 *****
# ExplainedVarNew: -0.00395
# ExplainedVarOld: -0.0352
# ValFuncLoss: 74.5
#
#
# ***** Episode 340, Mean Return = -343.1, Mean Discounted Return = -21.4 *****
# ExplainedVarNew: -0.0422
# ExplainedVarOld: -0.00163
# ValFuncLoss: 249
#
#
# ***** Episode 350, Mean Return = -224.2, Mean Discounted Return = -18.0 *****
# ExplainedVarNew: -0.483
# ExplainedVarOld: -0.409
# ValFuncLoss: 72.8
#
#
# ***** Episode 360, Mean Return = -322.8, Mean Discounted Return = -19.5 *****
# ExplainedVarNew: -0.00519
# ExplainedVarOld: -0.0117
# ValFuncLoss: 94.3
#
#
# ***** Episode 370, Mean Return = -334.5, Mean Discounted Return = -18.4 *****
# ExplainedVarNew: -0.00706
# ExplainedVarOld: -0.0273
# ValFuncLoss: 84.1
#
#
# ***** Episode 380, Mean Return = -274.3, Mean Discounted Return = -20.6 *****
# ExplainedVarNew: -0.0052
# ExplainedVarOld: -0.0107
# ValFuncLoss: 75.1
#
#
# ***** Episode 390, Mean Return = -235.0, Mean Discounted Return = -15.4 *****
# ExplainedVarNew: -0.0481
# ExplainedVarOld: -0.0154
# ValFuncLoss: 70.2
#
#
# ***** Episode 400, Mean Return = -307.3, Mean Discounted Return = -18.5 *****
# ExplainedVarNew: -0.0218
# ExplainedVarOld: -0.0161
# ValFuncLoss: 64.7
#
#
# ***** Episode 410, Mean Return = -247.8, Mean Discounted Return = -16.3 *****
# ExplainedVarNew: -0.00407
# ExplainedVarOld: -0.0235
# ValFuncLoss: 54.7
#
#
# ***** Episode 420, Mean Return = -224.1, Mean Discounted Return = -18.1 *****
# ExplainedVarNew: -0.00742
# ExplainedVarOld: -0.00372
# ValFuncLoss: 26.5
#
#
# ***** Episode 430, Mean Return = -196.8, Mean Discounted Return = -11.5 *****
# ExplainedVarNew: -0.0248
# ExplainedVarOld: -0.0414
# ValFuncLoss: 50.1
#
#
# ***** Episode 440, Mean Return = -228.7, Mean Discounted Return = -15.7 *****
# ExplainedVarNew: -0.000211
# ExplainedVarOld: -0.000567
# ValFuncLoss: 59.3
#
#
# ***** Episode 450, Mean Return = -201.4, Mean Discounted Return = -13.1 *****
# ExplainedVarNew: -1.22e-09
# ExplainedVarOld: -1.64e-09
# ValFuncLoss: 36.6
#
#
# ***** Episode 460, Mean Return = -315.6, Mean Discounted Return = -17.7 *****
# ExplainedVarNew: -0.00016
# ExplainedVarOld: -0.000254
# ValFuncLoss: 463
#
#
# ***** Episode 470, Mean Return = -188.1, Mean Discounted Return = -16.8 *****
# ExplainedVarNew: -0.00301
# ExplainedVarOld: -0.00416
# ValFuncLoss: 59.2
#
#
# ***** Episode 480, Mean Return = -257.0, Mean Discounted Return = -15.5 *****
# ExplainedVarNew: -0.000121
# ExplainedVarOld: -0.000664
# ValFuncLoss: 71.3
#
#
# ***** Episode 490, Mean Return = -253.7, Mean Discounted Return = -16.4 *****
# ExplainedVarNew: -0.00204
# ExplainedVarOld: -9.55e-05
# ValFuncLoss: 143
#
#
# ***** Episode 500, Mean Return = -238.8, Mean Discounted Return = -16.8 *****
# ExplainedVarNew: -0.00397
# ExplainedVarOld: -0.00293
# ValFuncLoss: 41.6
#
#
# ***** Episode 510, Mean Return = -178.6, Mean Discounted Return = -11.4 *****
# ExplainedVarNew: -0.0264
# ExplainedVarOld: -0.0274
# ValFuncLoss: 33.4
#
#
# ***** Episode 520, Mean Return = -221.3, Mean Discounted Return = -13.9 *****
# ExplainedVarNew: -0.0223
# ExplainedVarOld: -0.0178
# ValFuncLoss: 60.9
#
#
# ***** Episode 530, Mean Return = -191.3, Mean Discounted Return = -8.2 *****
# ExplainedVarNew: -0.00562
# ExplainedVarOld: -0.00342
# ValFuncLoss: 54
#
#
# ***** Episode 540, Mean Return = -148.5, Mean Discounted Return = -9.1 *****
# ExplainedVarNew: -0.000243
# ExplainedVarOld: -0.0285
# ValFuncLoss: 18
#
#
# ***** Episode 550, Mean Return = -393.5, Mean Discounted Return = -20.3 *****
# ExplainedVarNew: -7.89e-06
# ExplainedVarOld: -3.72e-06
# ValFuncLoss: 558
# ***** Episode 560, Mean Return = -135.7, Mean Discounted Return = -7.9 *****
# ExplainedVarNew: -9.62e-06
# ExplainedVarOld: -1.16e-05
# ValFuncLoss: 90
#
#
# ***** Episode 570, Mean Return = -193.6, Mean Discounted Return = -12.4 *****
# ExplainedVarNew: -1.13e-07
# ExplainedVarOld: -0.000888
# ValFuncLoss: 38.1
#
#
# ***** Episode 580, Mean Return = -259.0, Mean Discounted Return = -13.0 *****
# ExplainedVarNew: -0.00155
# ExplainedVarOld: -0.00249
# ValFuncLoss: 79.2
#
#
# ***** Episode 590, Mean Return = -220.7, Mean Discounted Return = -15.6 *****
# ExplainedVarNew: -0.00324
# ExplainedVarOld: -0.00152
# ValFuncLoss: 42.9
#
#
# ***** Episode 600, Mean Return = -218.9, Mean Discounted Return = -14.1 *****
# ExplainedVarNew: -0.00189
# ExplainedVarOld: -0.00113
# ValFuncLoss: 37
#
#
# ***** Episode 610, Mean Return = -261.9, Mean Discounted Return = -17.4 *****
# ExplainedVarNew: -0.0155
# ExplainedVarOld: -0.00808
# ValFuncLoss: 56.5
#
#
# ***** Episode 620, Mean Return = -156.7, Mean Discounted Return = -9.3 *****
# ExplainedVarNew: -0.0028
# ExplainedVarOld: -0.303
# ValFuncLoss: 17
#
#
# ***** Episode 630, Mean Return = -198.4, Mean Discounted Return = -10.8 *****
# ExplainedVarNew: -4.16e-05
# ExplainedVarOld: -0.000305
# ValFuncLoss: 24.8
#
#
# ***** Episode 640, Mean Return = -137.4, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.000109
# ExplainedVarOld: -0.00771
# ValFuncLoss: 10.2
#
#
# ***** Episode 650, Mean Return = -191.1, Mean Discounted Return = -14.5 *****
# ExplainedVarNew: -0.00614
# ExplainedVarOld: -0.089
# ValFuncLoss: 41.4
#
#
# ***** Episode 660, Mean Return = -145.2, Mean Discounted Return = -11.0 *****
# ExplainedVarNew: -0.000133
# ExplainedVarOld: -4.34e-08
# ValFuncLoss: 12.4
#
#
# ***** Episode 670, Mean Return = -129.4, Mean Discounted Return = -9.4 *****
# ExplainedVarNew: -2.03e-05
# ExplainedVarOld: -0.00418
# ValFuncLoss: 45.5
#
#
# ***** Episode 680, Mean Return = -185.7, Mean Discounted Return = -12.2 *****
# ExplainedVarNew: -0.00281
# ExplainedVarOld: -1.05e-05
# ValFuncLoss: 30
#
#
# ***** Episode 690, Mean Return = -186.5, Mean Discounted Return = -10.2 *****
# ExplainedVarNew: -1.89e-06
# ExplainedVarOld: -1.79e-08
# ValFuncLoss: 18.4
#
#
# ***** Episode 700, Mean Return = -144.0, Mean Discounted Return = -7.7 *****
# ExplainedVarNew: -0.000444
# ExplainedVarOld: -0.00345
# ValFuncLoss: 10.8
#
#
# ***** Episode 710, Mean Return = -174.3, Mean Discounted Return = -13.0 *****
# ExplainedVarNew: -5.08e-05
# ExplainedVarOld: -0.0471
# ValFuncLoss: 19.3
#
#
# ***** Episode 720, Mean Return = -149.1, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.000209
# ExplainedVarOld: -4.12e-07
# ValFuncLoss: 3.23
#
#
# ***** Episode 730, Mean Return = -156.4, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.00116
# ExplainedVarOld: -0.00963
# ValFuncLoss: 20.9
#
#
# ***** Episode 740, Mean Return = -174.1, Mean Discounted Return = -12.0 *****
# ExplainedVarNew: -0.00327
# ExplainedVarOld: -0.0152
# ValFuncLoss: 2.85
#
#
# ***** Episode 750, Mean Return = -134.9, Mean Discounted Return = -8.5 *****
# ExplainedVarNew: -4.14e-05
# ExplainedVarOld: -0.000258
# ValFuncLoss: 5.66
#
#
# ***** Episode 760, Mean Return = -197.5, Mean Discounted Return = -14.3 *****
# ExplainedVarNew: -2.23e-06
# ExplainedVarOld: -1.27e-05
# ValFuncLoss: 22.4
#
#
# ***** Episode 770, Mean Return = -149.8, Mean Discounted Return = -8.9 *****
# ExplainedVarNew: -7.84e-09
# ExplainedVarOld: -6.48e-11
# ValFuncLoss: 3.93
#
#
# ***** Episode 780, Mean Return = -184.9, Mean Discounted Return = -10.8 *****
# ExplainedVarNew: -0.00221
# ExplainedVarOld: -0.0124
# ValFuncLoss: 11.5
#
#
# ***** Episode 790, Mean Return = -158.8, Mean Discounted Return = -11.7 *****
# ExplainedVarNew: -0.142
# ExplainedVarOld: -0.000665
# ValFuncLoss: 10
#
#
# ***** Episode 800, Mean Return = -168.1, Mean Discounted Return = -8.7 *****
# ExplainedVarNew: -0.00165
# ExplainedVarOld: -0.199
# ValFuncLoss: 1.96
#
#
# ***** Episode 810, Mean Return = -98.3, Mean Discounted Return = -6.4 *****
# ExplainedVarNew: -0.00409
# ExplainedVarOld: -0.843
# ValFuncLoss: 11.6
#
#
# ***** Episode 820, Mean Return = -247.1, Mean Discounted Return = -12.8 *****
# ExplainedVarNew: -2.99e-06
# ExplainedVarOld: -5.76e-05
# ValFuncLoss: 154
#
#
# ***** Episode 830, Mean Return = -153.2, Mean Discounted Return = -9.9 *****
# ExplainedVarNew: -0.00766
# ExplainedVarOld: -0.0187
# ValFuncLoss: 8.36
#
#
# ***** Episode 840, Mean Return = -115.4, Mean Discounted Return = -6.6 *****
# ExplainedVarNew: -0.000266
# ExplainedVarOld: -0.0782
# ValFuncLoss: 8.14
#
#
# ***** Episode 850, Mean Return = -166.8, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -0.00462
# ExplainedVarOld: -0.00161
# ValFuncLoss: 1.37
#
#
# ***** Episode 860, Mean Return = -139.3, Mean Discounted Return = -9.8 *****
# ExplainedVarNew: -1.65e-06
# ExplainedVarOld: -2.37e-06
# ValFuncLoss: 9.52
#
#
# ***** Episode 870, Mean Return = -150.2, Mean Discounted Return = -7.8 *****
# ExplainedVarNew: -0.0101
# ExplainedVarOld: -0.000287
# ValFuncLoss: 2.96
#
#
# ***** Episode 880, Mean Return = -152.2, Mean Discounted Return = -10.1 *****
# ExplainedVarNew: -1.55e-08
# ExplainedVarOld: -1.33e-08
# ValFuncLoss: 5.05
#
#
# ***** Episode 890, Mean Return = -148.7, Mean Discounted Return = -7.9 *****
# ExplainedVarNew: -0.000249
# ExplainedVarOld: -0.000302
# ValFuncLoss: 3.11
#
#
# ***** Episode 900, Mean Return = -149.2, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.000484
# ExplainedVarOld: -0.00151
# ValFuncLoss: 3.28
#
#
# ***** Episode 910, Mean Return = -168.8, Mean Discounted Return = -11.0 *****
# ExplainedVarNew: -0.0553
# ExplainedVarOld: -0.00025
# ValFuncLoss: 38.1
#
#
# ***** Episode 920, Mean Return = -131.1, Mean Discounted Return = -6.9 *****
# ExplainedVarNew: -0.0134
# ExplainedVarOld: -0.00956
# ValFuncLoss: 5.39
#
#
# ***** Episode 930, Mean Return = -149.3, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.00926
# ExplainedVarOld: -0.0176
# ValFuncLoss: 3.35
#
#
# ***** Episode 940, Mean Return = -148.6, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -1.78e-05
# ExplainedVarOld: -3.48e-07
# ValFuncLoss: 3.06
#
#
# ***** Episode 950, Mean Return = -192.1, Mean Discounted Return = -11.0 *****
# ExplainedVarNew: -0.0657
# ExplainedVarOld: -0.155
# ValFuncLoss: 106
#
#
# ***** Episode 960, Mean Return = -113.8, Mean Discounted Return = -5.9 *****
# ExplainedVarNew: -0.00583
# ExplainedVarOld: -0.00543
# ValFuncLoss: 11.1
#
#
# ***** Episode 970, Mean Return = -171.3, Mean Discounted Return = -10.4 *****
# ExplainedVarNew: -0.0193
# ExplainedVarOld: -0.405
# ValFuncLoss: 4.09
#
#
# ***** Episode 980, Mean Return = -137.3, Mean Discounted Return = -11.2 *****
# ExplainedVarNew: -0.012
# ExplainedVarOld: -0.00823
# ValFuncLoss: 7.3
#
#
# ***** Episode 990, Mean Return = -167.1, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -0.00287
# ExplainedVarOld: -0.0661
# ValFuncLoss: 1.67
#
#
# ***** Episode 1000, Mean Return = -149.2, Mean Discounted Return = -8.2 *****
# ExplainedVarNew: -0.00053
# ExplainedVarOld: -0.00262
# ValFuncLoss: 3.1
#
#
# ***** Episode 1010, Mean Return = -130.9, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -8.36e-05
# ExplainedVarOld: -1.66
# ValFuncLoss: 5.19
#
#
# ***** Episode 1020, Mean Return = -148.6, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -1.37e-05
# ExplainedVarOld: -0.000121
# ValFuncLoss: 3.08
#
#
# ***** Episode 1030, Mean Return = -166.0, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -8.61e-07
# ExplainedVarOld: -1.32e-06
# ValFuncLoss: 1.33
#
#
# ***** Episode 1040, Mean Return = -133.2, Mean Discounted Return = -7.9 *****
# ExplainedVarNew: -1.01e-07
# ExplainedVarOld: -1.27e-07
# ValFuncLoss: 5.61
#
#
# ***** Episode 1050, Mean Return = -167.3, Mean Discounted Return = -8.6 *****
# ExplainedVarNew: -7.56e-07
# ExplainedVarOld: -7.46e-07
# ValFuncLoss: 1.52
#
#
# ***** Episode 1060, Mean Return = -98.0, Mean Discounted Return = -5.8 *****
# ExplainedVarNew: -5.14e-08
# ExplainedVarOld: -7.26e-08
# ValFuncLoss: 11.3
#
#
# ***** Episode 1070, Mean Return = -114.5, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0191
# ExplainedVarOld: -1.35
# ValFuncLoss: 7.62
#
#
# ***** Episode 1080, Mean Return = -137.4, Mean Discounted Return = -10.9 *****
# ExplainedVarNew: -1.55e-15
# ExplainedVarOld: 1.11e-16
# ValFuncLoss: 7.99
#
#
# ***** Episode 1090, Mean Return = -113.1, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -4.44e-16
# ExplainedVarOld: -1.11e-15
# ValFuncLoss: 7.82
#
#
# ***** Episode 1100, Mean Return = -132.4, Mean Discounted Return = -7.2 *****
# ExplainedVarNew: -0.0153
# ExplainedVarOld: -0.00267
# ValFuncLoss: 5.82
# ***** Episode 1110, Mean Return = -167.3, Mean Discounted Return = -9.0 *****
# ExplainedVarNew: -5.74e-05
# ExplainedVarOld: -0.00172
# ValFuncLoss: 1.42
#
#
# ***** Episode 1120, Mean Return = -149.1, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.00965
# ExplainedVarOld: -0.00945
# ValFuncLoss: 3.15
#
#
# ***** Episode 1130, Mean Return = -132.3, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -9.19e-09
# ExplainedVarOld: -7.7e-09
# ValFuncLoss: 5.44
#
#
# ***** Episode 1140, Mean Return = -149.4, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.00133
# ExplainedVarOld: -0.000131
# ValFuncLoss: 3.12
#
#
# ***** Episode 1150, Mean Return = -96.8, Mean Discounted Return = -4.6 *****
# ExplainedVarNew: -0.00333
# ExplainedVarOld: -0.000196
# ValFuncLoss: 11.6
#
#
# ***** Episode 1160, Mean Return = -149.7, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.0168
# ExplainedVarOld: -0.0206
# ValFuncLoss: 3.24
#
#
# ***** Episode 1170, Mean Return = -131.0, Mean Discounted Return = -6.3 *****
# ExplainedVarNew: -0.00502
# ExplainedVarOld: -0.00874
# ValFuncLoss: 5.14
#
#
# ***** Episode 1180, Mean Return = -97.3, Mean Discounted Return = -4.4 *****
# ExplainedVarNew: -0.0178
# ExplainedVarOld: -0.00668
# ValFuncLoss: 11.5
#
#
# ***** Episode 1190, Mean Return = -164.2, Mean Discounted Return = -8.2 *****
# ExplainedVarNew: -3.93e-12
# ExplainedVarOld: -1.28e-11
# ValFuncLoss: 1.33
#
#
# ***** Episode 1200, Mean Return = -150.3, Mean Discounted Return = -10.0 *****
# ExplainedVarNew: -0.000416
# ExplainedVarOld: -0.000781
# ValFuncLoss: 4.2
#
#
# ***** Episode 1210, Mean Return = -146.9, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: 1.11e-16
# ExplainedVarOld: 1.11e-16
# ValFuncLoss: 3.02
#
#
# ***** Episode 1220, Mean Return = -153.5, Mean Discounted Return = -8.2 *****
# ExplainedVarNew: -0.004
# ExplainedVarOld: -0.000131
# ValFuncLoss: 7.39
#
#
# ***** Episode 1230, Mean Return = -149.1, Mean Discounted Return = -6.9 *****
# ExplainedVarNew: -2.88e-12
# ExplainedVarOld: -2e-12
# ValFuncLoss: 3.06
#
#
# ***** Episode 1240, Mean Return = -149.3, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -2.9e-12
# ExplainedVarOld: -3.19e-12
# ValFuncLoss: 3.09
#
#
# ***** Episode 1250, Mean Return = -167.5, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -7.02e-14
# ExplainedVarOld: -1.29e-13
# ValFuncLoss: 1.36
#
#
# ***** Episode 1260, Mean Return = -168.3, Mean Discounted Return = -9.2 *****
# ExplainedVarNew: -4.11e-12
# ExplainedVarOld: -4.72e-12
# ValFuncLoss: 1.39
#
#
# ***** Episode 1270, Mean Return = -168.2, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -0.0153
# ExplainedVarOld: -0.0224
# ValFuncLoss: 1.41
#
#
# ***** Episode 1280, Mean Return = -131.7, Mean Discounted Return = -6.6 *****
# ExplainedVarNew: -0.00121
# ExplainedVarOld: -0.00197
# ValFuncLoss: 5.25
#
#
# ***** Episode 1290, Mean Return = -147.8, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -2.51e-14
# ExplainedVarOld: -1.22e-14
# ValFuncLoss: 3.08
#
#
# ***** Episode 1300, Mean Return = -130.1, Mean Discounted Return = -6.8 *****
# ExplainedVarNew: -0.000156
# ExplainedVarOld: -0.000181
# ValFuncLoss: 5.26
#
#
# ***** Episode 1310, Mean Return = -147.5, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.00516
# ExplainedVarOld: -0.00188
# ValFuncLoss: 3.06
#
#
# ***** Episode 1320, Mean Return = -148.9, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -7e-08
# ExplainedVarOld: -1.21e-07
# ValFuncLoss: 3.49
#
#
# ***** Episode 1330, Mean Return = -151.0, Mean Discounted Return = -9.4 *****
# ExplainedVarNew: -1.44e-09
# ExplainedVarOld: -1.56e-09
# ValFuncLoss: 4.05
#
#
# ***** Episode 1340, Mean Return = -192.9, Mean Discounted Return = -9.6 *****
# ExplainedVarNew: -5.83e-09
# ExplainedVarOld: -1.02e-05
# ValFuncLoss: 21.7
#
#
# ***** Episode 1350, Mean Return = -330.8, Mean Discounted Return = -18.0 *****
# ExplainedVarNew: -3.13e-10
# ExplainedVarOld: -1.26e-05
# ValFuncLoss: 566
#
#
# ***** Episode 1360, Mean Return = -144.5, Mean Discounted Return = -11.4 *****
# ExplainedVarNew: -0.00119
# ExplainedVarOld: -0.00104
# ValFuncLoss: 40.1
#
#
# ***** Episode 1370, Mean Return = -149.5, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.000357
# ExplainedVarOld: -0.0514
# ValFuncLoss: 3.07
#
#
# ***** Episode 1380, Mean Return = -113.9, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.000555
# ExplainedVarOld: -0.000819
# ValFuncLoss: 7.86
#
#
# ***** Episode 1390, Mean Return = -149.6, Mean Discounted Return = -7.9 *****
# ExplainedVarNew: -0.00139
# ExplainedVarOld: -0.000651
# ValFuncLoss: 3.17
#
#
# ***** Episode 1400, Mean Return = -149.8, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.0342
# ExplainedVarOld: -0.243
# ValFuncLoss: 3.3
#
#
# ***** Episode 1410, Mean Return = -96.9, Mean Discounted Return = -5.0 *****
# ExplainedVarNew: -0.0118
# ExplainedVarOld: -0.00751
# ValFuncLoss: 11.6
#
#
# ***** Episode 1420, Mean Return = -129.6, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.0326
# ExplainedVarOld: -0.0397
# ValFuncLoss: 5.34
#
#
# ***** Episode 1430, Mean Return = -147.3, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.0028
# ExplainedVarOld: -4.64
# ValFuncLoss: 3.09
#
#
# ***** Episode 1440, Mean Return = -146.8, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -1.77e-05
# ExplainedVarOld: -3.58e-05
# ValFuncLoss: 3.02
#
#
# ***** Episode 1450, Mean Return = -148.6, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.0111
# ExplainedVarOld: -0.198
# ValFuncLoss: 3.15
#
#
# ***** Episode 1460, Mean Return = -148.2, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.000663
# ExplainedVarOld: -0.0194
# ValFuncLoss: 3.12
#
#
# ***** Episode 1470, Mean Return = -166.4, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -7.22e-05
# ExplainedVarOld: -0.000387
# ValFuncLoss: 1.34
#
#
# ***** Episode 1480, Mean Return = -167.0, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -2.11e-05
# ExplainedVarOld: -2.67e-05
# ValFuncLoss: 1.35
#
#
# ***** Episode 1490, Mean Return = -167.3, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -0.00184
# ExplainedVarOld: -9.83e-05
# ValFuncLoss: 1.35
#
#
# ***** Episode 1500, Mean Return = -132.2, Mean Discounted Return = -6.8 *****
# ExplainedVarNew: -0.00072
# ExplainedVarOld: -0.00113
# ValFuncLoss: 5.32
#
#
# ***** Episode 1510, Mean Return = -149.1, Mean Discounted Return = -7.2 *****
# ExplainedVarNew: -0.00437
# ExplainedVarOld: -0.00945
# ValFuncLoss: 2.99
#
#
# ***** Episode 1520, Mean Return = -168.0, Mean Discounted Return = -9.0 *****
# ExplainedVarNew: -0.00324
# ExplainedVarOld: -0.00187
# ValFuncLoss: 1.63
#
#
# ***** Episode 1530, Mean Return = -148.6, Mean Discounted Return = -7.7 *****
# ExplainedVarNew: -0.000594
# ExplainedVarOld: -0.00033
# ValFuncLoss: 3.15
#
#
# ***** Episode 1540, Mean Return = -147.8, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.000136
# ExplainedVarOld: -1.65e-05
# ValFuncLoss: 3.05
#
#
# ***** Episode 1550, Mean Return = -112.9, Mean Discounted Return = -5.6 *****
# ExplainedVarNew: -0.000855
# ExplainedVarOld: -0.000416
# ValFuncLoss: 7.77
#
#
# ***** Episode 1560, Mean Return = -147.8, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.0135
# ExplainedVarOld: -0.00443
# ValFuncLoss: 3.11
#
#
# ***** Episode 1570, Mean Return = -152.8, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.00767
# ExplainedVarOld: -0.00959
# ValFuncLoss: 6.22
#
#
# ***** Episode 1580, Mean Return = -167.1, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -0.00884
# ExplainedVarOld: -0.172
# ValFuncLoss: 1.39
#
#
# ***** Episode 1590, Mean Return = -131.0, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.0207
# ExplainedVarOld: -0.0175
# ValFuncLoss: 5.25
#
#
# ***** Episode 1600, Mean Return = -148.8, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -9.1e-05
# ExplainedVarOld: -0.000162
# ValFuncLoss: 3.11
#
#
# ***** Episode 1610, Mean Return = -148.7, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.0492
# ExplainedVarOld: -0.0659
# ValFuncLoss: 3.18
#
#
# ***** Episode 1620, Mean Return = -167.1, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -0.00991
# ExplainedVarOld: -5.6
# ValFuncLoss: 1.37
#
#
# ***** Episode 1630, Mean Return = -113.5, Mean Discounted Return = -5.5 *****
# ExplainedVarNew: -4.7e-09
# ExplainedVarOld: -7.62e-09
# ValFuncLoss: 7.74
#
#
# ***** Episode 1640, Mean Return = -130.7, Mean Discounted Return = -6.4 *****
# ExplainedVarNew: -4.64e-05
# ExplainedVarOld: -0.000113
# ValFuncLoss: 5.13
#
#
# ***** Episode 1650, Mean Return = -166.0, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -0.00203
# ExplainedVarOld: -0.0741
# ValFuncLoss: 1.35
# ***** Episode 1660, Mean Return = -130.7, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.000235
# ExplainedVarOld: -6.26e-06
# ValFuncLoss: 5.21
#
#
# ***** Episode 1670, Mean Return = -148.6, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.00436
# ExplainedVarOld: -0.00839
# ValFuncLoss: 3.15
#
#
# ***** Episode 1680, Mean Return = -113.2, Mean Discounted Return = -5.5 *****
# ExplainedVarNew: -0.0161
# ExplainedVarOld: -0.00113
# ValFuncLoss: 7.92
#
#
# ***** Episode 1690, Mean Return = -149.4, Mean Discounted Return = -8.2 *****
# ExplainedVarNew: -0.00321
# ExplainedVarOld: -0.0692
# ValFuncLoss: 3.18
#
#
# ***** Episode 1700, Mean Return = -166.2, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -9.19e-11
# ExplainedVarOld: -1.79e-10
# ValFuncLoss: 1.33
#
#
# ***** Episode 1710, Mean Return = -149.6, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.0115
# ExplainedVarOld: -6.34
# ValFuncLoss: 3.13
#
#
# ***** Episode 1720, Mean Return = -114.2, Mean Discounted Return = -5.9 *****
# ExplainedVarNew: -0.0229
# ExplainedVarOld: -0.00348
# ValFuncLoss: 8.27
#
#
# ***** Episode 1730, Mean Return = -148.4, Mean Discounted Return = -7.3 *****
# ExplainedVarNew: -0.00498
# ExplainedVarOld: -0.656
# ValFuncLoss: 3.04
#
#
# ***** Episode 1740, Mean Return = -130.5, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.0136
# ExplainedVarOld: -0.00144
# ValFuncLoss: 5.04
#
#
# ***** Episode 1750, Mean Return = -147.9, Mean Discounted Return = -6.9 *****
# ExplainedVarNew: -4.08e-05
# ExplainedVarOld: -1.4e-05
# ValFuncLoss: 2.85
#
#
# ***** Episode 1760, Mean Return = -149.6, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.00508
# ExplainedVarOld: -0.0186
# ValFuncLoss: 3.22
#
#
# ***** Episode 1770, Mean Return = -148.1, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.000251
# ExplainedVarOld: -0.0454
# ValFuncLoss: 2.97
#
#
# ***** Episode 1780, Mean Return = -149.5, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.0537
# ExplainedVarOld: -0.0169
# ValFuncLoss: 3.32
#
#
# ***** Episode 1790, Mean Return = -148.0, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.0559
# ExplainedVarOld: -0.0389
# ValFuncLoss: 3.23
#
#
# ***** Episode 1800, Mean Return = -112.7, Mean Discounted Return = -5.4 *****
# ExplainedVarNew: -4.85e-06
# ExplainedVarOld: -4.35e-05
# ValFuncLoss: 7.7
#
#
# ***** Episode 1810, Mean Return = -130.8, Mean Discounted Return = -6.5 *****
# ExplainedVarNew: -0.0343
# ExplainedVarOld: -0.0351
# ValFuncLoss: 5.35
#
#
# ***** Episode 1820, Mean Return = -166.1, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -0.00273
# ExplainedVarOld: -0.00385
# ValFuncLoss: 1.37
#
#
# ***** Episode 1830, Mean Return = -148.6, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -0.0596
# ExplainedVarOld: -0.0528
# ValFuncLoss: 3.28
#
#
# ***** Episode 1840, Mean Return = -132.1, Mean Discounted Return = -6.2 *****
# ExplainedVarNew: -0.0526
# ExplainedVarOld: -0.0574
# ValFuncLoss: 5.39
#
#
# ***** Episode 1850, Mean Return = -148.8, Mean Discounted Return = -7.6 *****
# ExplainedVarNew: -0.00614
# ExplainedVarOld: -0.00343
# ValFuncLoss: 3.16
#
#
# ***** Episode 1860, Mean Return = -165.9, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -2.09e-10
# ExplainedVarOld: -1.92e-10
# ValFuncLoss: 1.34
#
#
# ***** Episode 1870, Mean Return = -148.3, Mean Discounted Return = -7.5 *****
# ExplainedVarNew: -3.36e-07
# ExplainedVarOld: -0.000115
# ValFuncLoss: 3.09
#
#
# ***** Episode 1880, Mean Return = -130.8, Mean Discounted Return = -6.6 *****
# ExplainedVarNew: -0.0441
# ExplainedVarOld: -0.0437
# ValFuncLoss: 5.45
#
#
# ***** Episode 1890, Mean Return = -188.6, Mean Discounted Return = -9.8 *****
# ExplainedVarNew: -0.00195
# ExplainedVarOld: -0.0105
# ValFuncLoss: 15.3
#
#
# ***** Episode 1900, Mean Return = -131.0, Mean Discounted Return = -6.7 *****
# ExplainedVarNew: -0.0464
# ExplainedVarOld: -0.0459
# ValFuncLoss: 6.04
#
#
# ***** Episode 1910, Mean Return = -166.1, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -9.4e-06
# ExplainedVarOld: -2.6e-06
# ValFuncLoss: 1.35
#
#
# ***** Episode 1920, Mean Return = -131.2, Mean Discounted Return = -6.7 *****
# ExplainedVarNew: -3.92e-05
# ExplainedVarOld: -6.02e-05
# ValFuncLoss: 5.24
#
#
# ***** Episode 1930, Mean Return = -166.5, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -0.00099
# ExplainedVarOld: -0.302
# ValFuncLoss: 1.35
#
#
# ***** Episode 1940, Mean Return = -167.6, Mean Discounted Return = -8.4 *****
# ExplainedVarNew: -0.0283
# ExplainedVarOld: -0.00143
# ValFuncLoss: 1.43
#
#
# ***** Episode 1950, Mean Return = -166.0, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -0.000403
# ExplainedVarOld: -0.000534
# ValFuncLoss: 1.33
#
#
# ***** Episode 1960, Mean Return = -148.2, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -2.33e-11
# ExplainedVarOld: -2.65e-11
# ValFuncLoss: 3.06
#
#
# ***** Episode 1970, Mean Return = -147.9, Mean Discounted Return = -7.1 *****
# ExplainedVarNew: -0.000332
# ExplainedVarOld: -0.000378
# ValFuncLoss: 2.96
#
#
# ***** Episode 1980, Mean Return = -130.3, Mean Discounted Return = -6.1 *****
# ExplainedVarNew: -0.000289
# ExplainedVarOld: -0.00235
# ValFuncLoss: 5.02
#
#
# ***** Episode 1990, Mean Return = -165.8, Mean Discounted Return = -8.3 *****
# ExplainedVarNew: -3.13e-12
# ExplainedVarOld: -7.84e-09
# ValFuncLoss: 1.33
#
#
# ***** Episode 2000, Mean Return = -148.5, Mean Discounted Return = -7.4 *****
# ExplainedVarNew: -0.00203
# ExplainedVarOld: -0.194
# ValFuncLoss: 3.07

# %% [markdown]
# # Discrete State Space - KL PO
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
env_name = 'Taxi-v3'
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyKL(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 1000
batch_eps = 60
logger = Logger(logname=env_name + '_DR-KL_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        policy.update(observes, actions, advantages, disc_freqs, env_name, eps)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()

# %% [markdown]
# ## Generate Expert Trajectories

# %%
from stable_baselines import PPO2
from stable_baselines.gail import generate_expert_traj

# Generate expert trajectories (train expert)
model = PPO2('MlpPolicy', 'Taxi-v3', verbose=1)
# Train for 60000 timesteps and record 10 trajectories
# all the data will be saved in 'expert_pendulum.npz' file
generate_expert_traj(model, 'expert_taxi', n_timesteps=600000, n_episodes=10)
