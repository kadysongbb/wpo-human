# %%
import gym
from datetime import datetime
import numpy as np
from scipy.stats import entropy

# DR TRPO related files
from train_helper import *
from value import NNValueFunction
from utils import Logger
from dr_policy import DRPolicyKL, DRPolicyWass, DRPolicySinkhorn

import tensorflow as tf
import tensorflow.contrib.distributions as dist
import tensorflow.contrib.layers as layers

# %% [markdown]
# ## Discriminator Network Setup

# %%
class Discriminator:
    def __init__(self, sess, hidden_size, lr, name):
        self.sess = sess
        self.hidden_size = hidden_size
        self.lr = lr
        self.name = name

        self.ob_ac = tf.placeholder(dtype=tf.float32, shape=[None, 2])
        
        with tf.variable_scope(name):
            self._build_network()

    def _build_network(self):
        with tf.variable_scope('discriminator'):
            d_h1 = layers.fully_connected(self.ob_ac, self.hidden_size, activation_fn=tf.tanh)
            d_h2 = layers.fully_connected(d_h1, self.hidden_size, activation_fn=tf.tanh)
            d_out = layers.fully_connected(d_h2, 1, activation_fn=None)

        self.reward = - tf.squeeze(tf.log(tf.sigmoid(d_out)))
        
        expert_out, policy_out = tf.split(d_out, num_or_size_splits=2, axis=0)

        self.loss = (tf.losses.sigmoid_cross_entropy(tf.ones_like(policy_out), policy_out)
                     + tf.losses.sigmoid_cross_entropy(tf.zeros_like(expert_out), expert_out))
        
        with tf.name_scope('train_op'):
            grads = tf.gradients(self.loss, self.params())
            self.grads = list(zip(grads, self.params()))
            self.train_op = tf.train.AdamOptimizer(self.lr).apply_gradients(self.grads)

    def params(self):
        return tf.global_variables(self.name).copy()

    def get_reward(self, expert_ob_ac):
        feed_dict = {self.ob_ac: expert_ob_ac}

        return self.sess.run(self.reward, feed_dict=feed_dict)

    def update(self, all_ob_ac):
        feed_dict = {self.ob_ac: all_ob_ac}

        self.sess.run(self.train_op, feed_dict=feed_dict)

# %% [markdown]
# # Discrete State Space - SPO + GAIL
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
config = tf.ConfigProto(
device_count={'GPU': 1},
intra_op_parallelism_threads=1,
allow_soft_placement=True
)
config.gpu_options.allow_growth = True
sess = tf.InteractiveSession(config=config)
tf.keras.backend.set_session(sess)
discriminator = Discriminator(sess, 10, 0.01, 'D')
sess.run(tf.global_variables_initializer())
tf.reset_default_graph()

env_name = 'Taxi-v3'
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicySinkhorn(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
gae_weight = 1
total_eps = 2000
batch_eps = 10
timesteps = 0
logger = Logger(logname=env_name + '_DR-Sinkhorn_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        # weight for RL
        lamb = 0.9
        # the randomness of the actions an agent takes can be quantified by the entropy
        entro = entropy(policy.distributions)
        trajectories = run_policy(env, policy, batch_eps, discriminator, lamb, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)
        # calculate advantage
        add_gae(trajectories, gamma, gae_weight)
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        timesteps += len(observes)
        logger.log({'_Timesteps': timesteps})
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs, env_name, eps)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True)
        
        policy_ob_ac = np.stack((observes, actions),1)
        data = np.load('expert_traj/expert_taxi.npz')
        expert_obs = data['obs'].T[0]
        expert_actions = data['actions'].T[0]
        expert_ob_ac = np.stack((expert_obs, expert_actions),1)
        min_len = min(len(expert_ob_ac), len(policy_ob_ac))
        discriminator.update(np.concatenate([expert_ob_ac[:min_len], policy_ob_ac[:min_len]], axis=0))
logger.close()
sess.close()
# Out:
# /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 10, Timesteps 1871, Mean Return = -658.6  *****
# ExplainedVarNew: -2.21e-09
# ExplainedVarOld: -3.7e-05
# ValFuncLoss: 941
#
#
# ***** Episode 20, Timesteps 3871, Mean Return = -687.4  *****
# ExplainedVarNew: -2.85e-10
# ExplainedVarOld: -2.79e-11
# ValFuncLoss: 750
#
#
# ***** Episode 30, Timesteps 5871, Mean Return = -638.7  *****
# ExplainedVarNew: -9e-09
# ExplainedVarOld: -1.66e-07
# ValFuncLoss: 478
#
#
# ***** Episode 40, Timesteps 7871, Mean Return = -677.6  *****
# ExplainedVarNew: -1.41e-09
# ExplainedVarOld: -4.98e-09
# ValFuncLoss: 460
#
#
# ***** Episode 50, Timesteps 9871, Mean Return = -652.7  *****
# ExplainedVarNew: -1.2e-10
# ExplainedVarOld: -2.65e-10
# ValFuncLoss: 330
#
#
# ***** Episode 60, Timesteps 11871, Mean Return = -608.4  *****
# ExplainedVarNew: -1e-11
# ExplainedVarOld: -1.54e-11
# ValFuncLoss: 221
#
#
# ***** Episode 70, Timesteps 13867, Mean Return = -632.8  *****
# ExplainedVarNew: -3.3e-10
# ExplainedVarOld: -4.59e-10
# ValFuncLoss: 211
#
#
# ***** Episode 80, Timesteps 15867, Mean Return = -559.2  *****
# ExplainedVarNew: -2.51e-11
# ExplainedVarOld: -3.18e-11
# ValFuncLoss: 122
#
#
# ***** Episode 90, Timesteps 17867, Mean Return = -553.7  *****
# ExplainedVarNew: -6.97e-11
# ExplainedVarOld: -8.04e-11
# ValFuncLoss: 99.6
#
#
# ***** Episode 100, Timesteps 19867, Mean Return = -552.1  *****
# ExplainedVarNew: -9.38e-10
# ExplainedVarOld: -1.06e-09
# ValFuncLoss: 87.9
#
#
# ***** Episode 110, Timesteps 21851, Mean Return = -532.8  *****
# ExplainedVarNew: -8.54e-11
# ExplainedVarOld: -9.1e-11
# ValFuncLoss: 96.2
#
#
# ***** Episode 120, Timesteps 23851, Mean Return = -528.1  *****
# ExplainedVarNew: -7.58e-10
# ExplainedVarOld: -7.79e-10
# ValFuncLoss: 70.8
#
#
# ***** Episode 130, Timesteps 25742, Mean Return = -481.1  *****
# ExplainedVarNew: -3.03e-10
# ExplainedVarOld: -2.92e-10
# ValFuncLoss: 77
#
#
# ***** Episode 140, Timesteps 27742, Mean Return = -514.5  *****
# ExplainedVarNew: -3.06e-11
# ExplainedVarOld: -2.93e-11
# ValFuncLoss: 94.5
#
#
# ***** Episode 150, Timesteps 29742, Mean Return = -468.3  *****
# ExplainedVarNew: -1.49e-09
# ExplainedVarOld: -9.75e-10
# ValFuncLoss: 77.3
#
#
# ***** Episode 160, Timesteps 31742, Mean Return = -458.7  *****
# ExplainedVarNew: -2.56e-11
# ExplainedVarOld: -1.77e-11
# ValFuncLoss: 64.1
#
#
# ***** Episode 170, Timesteps 33742, Mean Return = -473.7  *****
# ExplainedVarNew: -2.66e-08
# ExplainedVarOld: -1.23e-09
# ValFuncLoss: 83.5
#
#
# ***** Episode 180, Timesteps 35742, Mean Return = -516.2  *****
# ExplainedVarNew: -0.000281
# ExplainedVarOld: -8.25e-10
# ValFuncLoss: 103
#
#
# ***** Episode 190, Timesteps 37742, Mean Return = -458.3  *****
# ExplainedVarNew: -0.00163
# ExplainedVarOld: -0.00656
# ValFuncLoss: 72.9
#
#
# ***** Episode 200, Timesteps 39742, Mean Return = -441.7  *****
# ExplainedVarNew: -9.48e-05
# ExplainedVarOld: -0.000355
# ValFuncLoss: 71.5
#
#
# ***** Episode 210, Timesteps 41742, Mean Return = -476.0  *****
# ExplainedVarNew: -1e-05
# ExplainedVarOld: -0.000773
# ValFuncLoss: 82.5
#
#
# ***** Episode 220, Timesteps 43637, Mean Return = -419.2  *****
# ExplainedVarNew: -2.55e-06
# ExplainedVarOld: -4.75e-08
# ValFuncLoss: 76.6
#
#
# ***** Episode 230, Timesteps 45637, Mean Return = -469.9  *****
# ExplainedVarNew: -2.19e-07
# ExplainedVarOld: -3.01e-07
# ValFuncLoss: 80.5
#
#
# ***** Episode 240, Timesteps 47637, Mean Return = -428.7  *****
# ExplainedVarNew: -2.75e-06
# ExplainedVarOld: -6.5e-07
# ValFuncLoss: 62.9
#
#
# ***** Episode 250, Timesteps 49478, Mean Return = -340.5  *****
# ExplainedVarNew: -0.000189
# ExplainedVarOld: -9.55e-07
# ValFuncLoss: 62.2
#
#
# ***** Episode 260, Timesteps 51478, Mean Return = -432.5  *****
# ExplainedVarNew: -9.12e-05
# ExplainedVarOld: -2.91e-05
# ValFuncLoss: 73
#
#
# ***** Episode 270, Timesteps 53478, Mean Return = -433.9  *****
# ExplainedVarNew: -0.00011
# ExplainedVarOld: -0.000103
# ValFuncLoss: 70.5
#
#
# ***** Episode 280, Timesteps 55412, Mean Return = -453.1  *****
# ExplainedVarNew: -0.00014
# ExplainedVarOld: -0.00142
# ValFuncLoss: 84.2
#
#
# ***** Episode 290, Timesteps 57412, Mean Return = -392.2  *****
# ExplainedVarNew: -2.09e-08
# ExplainedVarOld: -3.3e-07
# ValFuncLoss: 73.3
#
#
# ***** Episode 300, Timesteps 59328, Mean Return = -434.2  *****
# ExplainedVarNew: -0.00115
# ExplainedVarOld: -0.000918
# ValFuncLoss: 75.4
#
#
# ***** Episode 310, Timesteps 61296, Mean Return = -480.5  *****
# ExplainedVarNew: -0.00015
# ExplainedVarOld: -0.00362
# ValFuncLoss: 84.7
#
#
# ***** Episode 320, Timesteps 62957, Mean Return = -365.5  *****
# ExplainedVarNew: -4.7e-07
# ExplainedVarOld: -4.54e-07
# ValFuncLoss: 83.2
#
#
# ***** Episode 330, Timesteps 64957, Mean Return = -433.9  *****
# ExplainedVarNew: -0.000996
# ExplainedVarOld: -0.000276
# ValFuncLoss: 68.6
#
#
# ***** Episode 340, Timesteps 66717, Mean Return = -336.5  *****
# ExplainedVarNew: -0.000111
# ExplainedVarOld: -0.000614
# ValFuncLoss: 71.5
#
#
# ***** Episode 350, Timesteps 68644, Mean Return = -363.4  *****
# ExplainedVarNew: -7.29e-05
# ExplainedVarOld: -1.44e-07
# ValFuncLoss: 55.6
#
#
# ***** Episode 360, Timesteps 70644, Mean Return = -384.5  *****
# ExplainedVarNew: -0.00111
# ExplainedVarOld: -6.24e-05
# ValFuncLoss: 51.1
#
#
# ***** Episode 370, Timesteps 72491, Mean Return = -357.9  *****
# ExplainedVarNew: -0.000732
# ExplainedVarOld: -0.000938
# ValFuncLoss: 66.5
#
#
# ***** Episode 380, Timesteps 74236, Mean Return = -353.9  *****
# ExplainedVarNew: -0.00215
# ExplainedVarOld: -0.000184
# ValFuncLoss: 74.9
#
#
# ***** Episode 390, Timesteps 75840, Mean Return = -304.0  *****
# ExplainedVarNew: -0.0129
# ExplainedVarOld: -0.00508
# ValFuncLoss: 103
#
#
# ***** Episode 400, Timesteps 77664, Mean Return = -344.8  *****
# ExplainedVarNew: -0.00164
# ExplainedVarOld: -0.0232
# ValFuncLoss: 62.9
#
#
# ***** Episode 410, Timesteps 79492, Mean Return = -338.2  *****
# ExplainedVarNew: -0.000232
# ExplainedVarOld: -0.00165
# ValFuncLoss: 49
#
#
# ***** Episode 420, Timesteps 81120, Mean Return = -292.5  *****
# ExplainedVarNew: -0.00362
# ExplainedVarOld: -4.62e-05
# ValFuncLoss: 79.5
#
#
# ***** Episode 430, Timesteps 82630, Mean Return = -283.3  *****
# ExplainedVarNew: -0.0138
# ExplainedVarOld: -0.0151
# ValFuncLoss: 80.7
#
#
# ***** Episode 440, Timesteps 84282, Mean Return = -280.6  *****
# ExplainedVarNew: -0.00657
# ExplainedVarOld: -0.012
# ValFuncLoss: 72.1
#
#
# ***** Episode 450, Timesteps 86021, Mean Return = -325.3  *****
# ExplainedVarNew: -0.00663
# ExplainedVarOld: -0.053
# ValFuncLoss: 61.1
#
#
# ***** Episode 460, Timesteps 87893, Mean Return = -324.8  *****
# ExplainedVarNew: -0.0347
# ExplainedVarOld: -0.0116
# ValFuncLoss: 57.4
#
#
# ***** Episode 470, Timesteps 89655, Mean Return = -326.5  *****
# ExplainedVarNew: -0.0106
# ExplainedVarOld: -0.0191
# ValFuncLoss: 77.4
#
#
# ***** Episode 480, Timesteps 91278, Mean Return = -268.3  *****
# ExplainedVarNew: -0.000118
# ExplainedVarOld: -0.00238
# ValFuncLoss: 63.5
#
#
# ***** Episode 490, Timesteps 92981, Mean Return = -305.8  *****
# ExplainedVarNew: -0.00219
# ExplainedVarOld: -0.000566
# ValFuncLoss: 65.4
#
#
# ***** Episode 500, Timesteps 94597, Mean Return = -308.2  *****
# ExplainedVarNew: -0.00398
# ExplainedVarOld: -0.000853
# ValFuncLoss: 66.9
#
#
# ***** Episode 510, Timesteps 96116, Mean Return = -298.6  *****
# ExplainedVarNew: -0.00023
# ExplainedVarOld: -0.00182
# ValFuncLoss: 75.2
#
#
# ***** Episode 520, Timesteps 97910, Mean Return = -354.6  *****
# ExplainedVarNew: -0.000324
# ExplainedVarOld: -0.000476
# ValFuncLoss: 76.2
#
#
# ***** Episode 530, Timesteps 98958, Mean Return = -173.7  *****
# ExplainedVarNew: -0.000615
# ExplainedVarOld: -9.98e-05
# ValFuncLoss: 112
#
#
# ***** Episode 540, Timesteps 100192, Mean Return = -266.4  *****
# ExplainedVarNew: -0.00413
# ExplainedVarOld: -0.00352
# ValFuncLoss: 125
#
#
# ***** Episode 550, Timesteps 101170, Mean Return = -152.7  *****
# ExplainedVarNew: -0.000168
# ExplainedVarOld: -0.000381
# ValFuncLoss: 112
#
#
# ***** Episode 560, Timesteps 102523, Mean Return = -283.8  *****
# ExplainedVarNew: -0.000321
# ExplainedVarOld: -0.000291
# ValFuncLoss: 109
#
#
# ***** Episode 570, Timesteps 103993, Mean Return = -272.0  *****
# ExplainedVarNew: -0.000386
# ExplainedVarOld: -0.000378
# ValFuncLoss: 72.3
#
#
# ***** Episode 580, Timesteps 105501, Mean Return = -285.1  *****
# ExplainedVarNew: -0.0004
# ExplainedVarOld: -0.000428
# ValFuncLoss: 85.4
#
#
# ***** Episode 590, Timesteps 106778, Mean Return = -216.1  *****
# ExplainedVarNew: -0.00948
# ExplainedVarOld: -0.000327
# ValFuncLoss: 75.4
#
#
# ***** Episode 600, Timesteps 108057, Mean Return = -226.3  *****
# ExplainedVarNew: -2.59e-06
# ExplainedVarOld: -0.00033
# ValFuncLoss: 88.7
# ***** Episode 610, Timesteps 109069, Mean Return = -178.0  *****
# ExplainedVarNew: -0.000107
# ExplainedVarOld: -7.27e-05
# ValFuncLoss: 101
#
#
# ***** Episode 620, Timesteps 110407, Mean Return = -297.7  *****
# ExplainedVarNew: -6.98e-05
# ExplainedVarOld: -5.38e-06
# ValFuncLoss: 120
#
#
# ***** Episode 630, Timesteps 111701, Mean Return = -269.5  *****
# ExplainedVarNew: -0.000512
# ExplainedVarOld: -0.000119
# ValFuncLoss: 131
#
#
# ***** Episode 640, Timesteps 112329, Mean Return = -86.3  *****
# ExplainedVarNew: -0.00104
# ExplainedVarOld: -3.19e-05
# ValFuncLoss: 139
#
#
# ***** Episode 650, Timesteps 113555, Mean Return = -231.9  *****
# ExplainedVarNew: -0.00882
# ExplainedVarOld: -0.00996
# ValFuncLoss: 108
#
#
# ***** Episode 660, Timesteps 114469, Mean Return = -165.8  *****
# ExplainedVarNew: -0.00436
# ExplainedVarOld: -0.00527
# ValFuncLoss: 108
#
#
# ***** Episode 670, Timesteps 115013, Mean Return = -102.6  *****
# ExplainedVarNew: -0.00915
# ExplainedVarOld: -0.00579
# ValFuncLoss: 207
#
#
# ***** Episode 680, Timesteps 116102, Mean Return = -219.6  *****
# ExplainedVarNew: -0.00382
# ExplainedVarOld: -0.00524
# ValFuncLoss: 130
#
#
# ***** Episode 690, Timesteps 117207, Mean Return = -227.1  *****
# ExplainedVarNew: -0.0192
# ExplainedVarOld: -0.0117
# ValFuncLoss: 125
#
#
# ***** Episode 700, Timesteps 118753, Mean Return = -300.4  *****
# ExplainedVarNew: -0.00398
# ExplainedVarOld: -0.0079
# ValFuncLoss: 79.1
#
#
# ***** Episode 710, Timesteps 120363, Mean Return = -373.6  *****
# ExplainedVarNew: -0.00697
# ExplainedVarOld: -0.243
# ValFuncLoss: 108
#
#
# ***** Episode 720, Timesteps 121363, Mean Return = -172.0  *****
# ExplainedVarNew: -0.00401
# ExplainedVarOld: -0.00117
# ValFuncLoss: 104
#
#
# ***** Episode 730, Timesteps 122443, Mean Return = -248.1  *****
# ExplainedVarNew: -0.00585
# ExplainedVarOld: -0.0118
# ValFuncLoss: 168
#
#
# ***** Episode 740, Timesteps 123729, Mean Return = -272.7  *****
# ExplainedVarNew: -0.00596
# ExplainedVarOld: -0.00945
# ValFuncLoss: 92.4
#
#
# ***** Episode 750, Timesteps 124880, Mean Return = -242.2  *****
# ExplainedVarNew: -0.00233
# ExplainedVarOld: -0.00308
# ValFuncLoss: 112
#
#
# ***** Episode 760, Timesteps 125736, Mean Return = -170.3  *****
# ExplainedVarNew: -4.57e-05
# ExplainedVarOld: -0.000254
# ValFuncLoss: 132
#
#
# ***** Episode 770, Timesteps 126985, Mean Return = -290.2  *****
# ExplainedVarNew: -0.000159
# ExplainedVarOld: -0.000219
# ValFuncLoss: 140
#
#
# ***** Episode 780, Timesteps 127663, Mean Return = -132.9  *****
# ExplainedVarNew: -0.00304
# ExplainedVarOld: -0.00217
# ValFuncLoss: 191
#
#
# ***** Episode 790, Timesteps 128846, Mean Return = -252.8  *****
# ExplainedVarNew: -0.0042
# ExplainedVarOld: -0.00229
# ValFuncLoss: 117
#
#
# ***** Episode 800, Timesteps 129965, Mean Return = -221.7  *****
# ExplainedVarNew: -0.00108
# ExplainedVarOld: -0.000518
# ValFuncLoss: 104
#
#
# ***** Episode 810, Timesteps 130820, Mean Return = -159.2  *****
# ExplainedVarNew: -0.000213
# ExplainedVarOld: -0.000492
# ValFuncLoss: 128
#
#
# ***** Episode 820, Timesteps 131777, Mean Return = -190.3  *****
# ExplainedVarNew: -0.000169
# ExplainedVarOld: -0.00123
# ValFuncLoss: 112
#
#
# ***** Episode 830, Timesteps 132477, Mean Return = -133.4  *****
# ExplainedVarNew: -0.00445
# ExplainedVarOld: -0.000611
# ValFuncLoss: 159
#
#
# ***** Episode 840, Timesteps 133466, Mean Return = -240.2  *****
# ExplainedVarNew: -0.00107
# ExplainedVarOld: -0.000638
# ValFuncLoss: 189
#
#
# ***** Episode 850, Timesteps 134269, Mean Return = -171.9  *****
# ExplainedVarNew: -0.000381
# ExplainedVarOld: -0.00364
# ValFuncLoss: 187
#
#
# ***** Episode 860, Timesteps 135219, Mean Return = -212.2  *****
# ExplainedVarNew: -0.00703
# ExplainedVarOld: -0.0123
# ValFuncLoss: 162
#
#
# ***** Episode 870, Timesteps 136300, Mean Return = -235.9  *****
# ExplainedVarNew: -0.004
# ExplainedVarOld: -0.0096
# ValFuncLoss: 129
#
#
# ***** Episode 880, Timesteps 137598, Mean Return = -265.5  *****
# ExplainedVarNew: -0.000363
# ExplainedVarOld: -0.000696
# ValFuncLoss: 80.7
#
#
# ***** Episode 890, Timesteps 138587, Mean Return = -175.2  *****
# ExplainedVarNew: -0.00148
# ExplainedVarOld: -0.0017
# ValFuncLoss: 101
#
#
# ***** Episode 900, Timesteps 139156, Mean Return = -107.9  *****
# ExplainedVarNew: -0.0118
# ExplainedVarOld: -0.00244
# ValFuncLoss: 217
#
#
# ***** Episode 910, Timesteps 140245, Mean Return = -208.4  *****
# ExplainedVarNew: -0.00421
# ExplainedVarOld: -0.004
# ValFuncLoss: 102
#
#
# ***** Episode 920, Timesteps 141046, Mean Return = -152.7  *****
# ExplainedVarNew: -0.00344
# ExplainedVarOld: -0.00712
# ValFuncLoss: 149
#
#
# ***** Episode 930, Timesteps 141698, Mean Return = -139.9  *****
# ExplainedVarNew: -0.000191
# ExplainedVarOld: -1.36e-05
# ValFuncLoss: 214
#
#
# ***** Episode 940, Timesteps 142380, Mean Return = -126.5  *****
# ExplainedVarNew: -0.00768
# ExplainedVarOld: -0.00289
# ValFuncLoss: 176
#
#
# ***** Episode 950, Timesteps 143371, Mean Return = -208.9  *****
# ExplainedVarNew: -0.00817
# ExplainedVarOld: -0.00975
# ValFuncLoss: 137
#
#
# ***** Episode 960, Timesteps 143973, Mean Return = -131.8  *****
# ExplainedVarNew: -0.00274
# ExplainedVarOld: -0.00386
# ValFuncLoss: 228
#
#
# ***** Episode 970, Timesteps 144943, Mean Return = -186.3  *****
# ExplainedVarNew: -0.000717
# ExplainedVarOld: -0.000535
# ValFuncLoss: 125
#
#
# ***** Episode 980, Timesteps 145838, Mean Return = -198.7  *****
# ExplainedVarNew: -0.00794
# ExplainedVarOld: -0.00881
# ValFuncLoss: 165
#
#
# ***** Episode 990, Timesteps 147003, Mean Return = -271.1  *****
# ExplainedVarNew: -0.00477
# ExplainedVarOld: -0.00581
# ValFuncLoss: 151
#
#
# ***** Episode 1000, Timesteps 147564, Mean Return = -95.5  *****
# ExplainedVarNew: -0.00311
# ExplainedVarOld: -0.00245
# ValFuncLoss: 189
#
#
# ***** Episode 1010, Timesteps 148219, Mean Return = -136.3  *****
# ExplainedVarNew: -0.00158
# ExplainedVarOld: -0.00103
# ValFuncLoss: 215
#
#
# ***** Episode 1020, Timesteps 149357, Mean Return = -256.2  *****
# ExplainedVarNew: -0.00366
# ExplainedVarOld: -0.00418
# ValFuncLoss: 145
#
#
# ***** Episode 1030, Timesteps 149762, Mean Return = -69.1  *****
# ExplainedVarNew: -0.0044
# ExplainedVarOld: -0.00471
# ValFuncLoss: 274
#
#
# ***** Episode 1040, Timesteps 150925, Mean Return = -256.5  *****
# ExplainedVarNew: -0.00414
# ExplainedVarOld: -0.00273
# ValFuncLoss: 144
#
#
# ***** Episode 1050, Timesteps 151206, Mean Return = -27.9  *****
# ExplainedVarNew: -0.00126
# ExplainedVarOld: -0.00116
# ValFuncLoss: 318
#
#
# ***** Episode 1060, Timesteps 152086, Mean Return = -212.0  *****
# ExplainedVarNew: -0.00458
# ExplainedVarOld: -0.001
# ValFuncLoss: 171
#
#
# ***** Episode 1070, Timesteps 152752, Mean Return = -125.8  *****
# ExplainedVarNew: -0.00832
# ExplainedVarOld: -0.00952
# ValFuncLoss: 186
#
#
# ***** Episode 1080, Timesteps 153498, Mean Return = -146.9  *****
# ExplainedVarNew: -0.00367
# ExplainedVarOld: -0.00334
# ValFuncLoss: 170
#
#
# ***** Episode 1090, Timesteps 154048, Mean Return = -116.9  *****
# ExplainedVarNew: -0.00786
# ExplainedVarOld: -0.00568
# ValFuncLoss: 211
#
#
# ***** Episode 1100, Timesteps 154743, Mean Return = -119.2  *****
# ExplainedVarNew: -0.0146
# ExplainedVarOld: -0.0105
# ValFuncLoss: 160
#
#
# ***** Episode 1110, Timesteps 155103, Mean Return = -63.7  *****
# ExplainedVarNew: -0.00712
# ExplainedVarOld: -0.00836
# ValFuncLoss: 304
#
#
# ***** Episode 1120, Timesteps 155750, Mean Return = -141.6  *****
# ExplainedVarNew: -0.00925
# ExplainedVarOld: -0.0061
# ValFuncLoss: 187
#
#
# ***** Episode 1130, Timesteps 156566, Mean Return = -173.3  *****
# ExplainedVarNew: -0.00368
# ExplainedVarOld: -0.00827
# ValFuncLoss: 155
#
#
# ***** Episode 1140, Timesteps 157429, Mean Return = -183.2  *****
# ExplainedVarNew: -0.00801
# ExplainedVarOld: -0.00742
# ValFuncLoss: 150
#
#
# ***** Episode 1150, Timesteps 158230, Mean Return = -172.3  *****
# ExplainedVarNew: -0.0108
# ExplainedVarOld: -0.00769
# ValFuncLoss: 139
#
#
# ***** Episode 1160, Timesteps 158965, Mean Return = -150.9  *****
# ExplainedVarNew: -0.00231
# ExplainedVarOld: -0.00747
# ValFuncLoss: 179
#
#
# ***** Episode 1170, Timesteps 159699, Mean Return = -143.5  *****
# ExplainedVarNew: -0.0314
# ExplainedVarOld: -0.032
# ValFuncLoss: 154
#
#
# ***** Episode 1180, Timesteps 160229, Mean Return = -114.5  *****
# ExplainedVarNew: -0.00648
# ExplainedVarOld: -0.00309
# ValFuncLoss: 244
#
#
# ***** Episode 1190, Timesteps 161263, Mean Return = -246.9  *****
# ExplainedVarNew: -0.012
# ExplainedVarOld: -0.0132
# ValFuncLoss: 157
#
#
# ***** Episode 1200, Timesteps 161979, Mean Return = -128.3  *****
# ExplainedVarNew: -0.0149
# ExplainedVarOld: -0.011
# ValFuncLoss: 181
#
#
# ***** Episode 1210, Timesteps 163038, Mean Return = -242.3  *****
# ExplainedVarNew: -0.0133
# ExplainedVarOld: -0.013
# ValFuncLoss: 147
#
#
# ***** Episode 1220, Timesteps 163415, Mean Return = -58.8  *****
# ExplainedVarNew: -0.0296
# ExplainedVarOld: -0.0579
# ValFuncLoss: 277
# ***** Episode 1230, Timesteps 164057, Mean Return = -138.8  *****
# ExplainedVarNew: -0.0046
# ExplainedVarOld: -0.00824
# ValFuncLoss: 209
#
#
# ***** Episode 1240, Timesteps 164918, Mean Return = -191.9  *****
# ExplainedVarNew: -0.0236
# ExplainedVarOld: -0.0171
# ValFuncLoss: 149
#
#
# ***** Episode 1250, Timesteps 166092, Mean Return = -272.5  *****
# ExplainedVarNew: -0.0376
# ExplainedVarOld: -0.0317
# ValFuncLoss: 140
#
#
# ***** Episode 1260, Timesteps 166474, Mean Return = -64.0  *****
# ExplainedVarNew: -0.0672
# ExplainedVarOld: -0.0527
# ValFuncLoss: 278
#
#
# ***** Episode 1270, Timesteps 167228, Mean Return = -183.0  *****
# ExplainedVarNew: -0.0218
# ExplainedVarOld: -0.0224
# ValFuncLoss: 241
#
#
# ***** Episode 1280, Timesteps 168034, Mean Return = -179.6  *****
# ExplainedVarNew: -0.0343
# ExplainedVarOld: -0.0397
# ValFuncLoss: 203
#
#
# ***** Episode 1290, Timesteps 168767, Mean Return = -168.0  *****
# ExplainedVarNew: -0.0604
# ExplainedVarOld: -0.0472
# ValFuncLoss: 177
#
#
# ***** Episode 1300, Timesteps 169434, Mean Return = -150.9  *****
# ExplainedVarNew: -0.0504
# ExplainedVarOld: -0.0428
# ValFuncLoss: 199
#
#
# ***** Episode 1310, Timesteps 170030, Mean Return = -113.9  *****
# ExplainedVarNew: -0.0872
# ExplainedVarOld: -0.0883
# ValFuncLoss: 210
#
#
# ***** Episode 1320, Timesteps 170526, Mean Return = -113.9  *****
# ExplainedVarNew: -0.0173
# ExplainedVarOld: -0.0164
# ValFuncLoss: 307
#
#
# ***** Episode 1330, Timesteps 171306, Mean Return = -179.4  *****
# ExplainedVarNew: -0.0363
# ExplainedVarOld: -0.0399
# ValFuncLoss: 193
#
#
# ***** Episode 1340, Timesteps 172001, Mean Return = -155.7  *****
# ExplainedVarNew: -0.0133
# ExplainedVarOld: -0.00819
# ValFuncLoss: 200
#
#
# ***** Episode 1350, Timesteps 172541, Mean Return = -112.1  *****
# ExplainedVarNew: -0.0299
# ExplainedVarOld: -0.0294
# ValFuncLoss: 216
#
#
# ***** Episode 1360, Timesteps 173272, Mean Return = -178.2  *****
# ExplainedVarNew: -0.0467
# ExplainedVarOld: -0.0438
# ValFuncLoss: 261
#
#
# ***** Episode 1370, Timesteps 173887, Mean Return = -149.3  *****
# ExplainedVarNew: -0.0661
# ExplainedVarOld: -0.0786
# ValFuncLoss: 319
#
#
# ***** Episode 1380, Timesteps 174669, Mean Return = -188.2  *****
# ExplainedVarNew: -0.0728
# ExplainedVarOld: -0.0814
# ValFuncLoss: 197
#
#
# ***** Episode 1390, Timesteps 175288, Mean Return = -149.4  *****
# ExplainedVarNew: -0.025
# ExplainedVarOld: -0.0263
# ValFuncLoss: 289
#
#
# ***** Episode 1400, Timesteps 176025, Mean Return = -182.4  *****
# ExplainedVarNew: -0.0529
# ExplainedVarOld: -0.0365
# ValFuncLoss: 216
#
#
# ***** Episode 1410, Timesteps 176774, Mean Return = -177.3  *****
# ExplainedVarNew: -0.0267
# ExplainedVarOld: -0.0221
# ValFuncLoss: 227
#
#
# ***** Episode 1420, Timesteps 177594, Mean Return = -181.3  *****
# ExplainedVarNew: -0.0594
# ExplainedVarOld: -0.137
# ValFuncLoss: 190
#
#
# ***** Episode 1430, Timesteps 178477, Mean Return = -211.8  *****
# ExplainedVarNew: -0.0586
# ExplainedVarOld: -0.0559
# ValFuncLoss: 156
#
#
# ***** Episode 1440, Timesteps 179097, Mean Return = -143.6  *****
# ExplainedVarNew: -0.0428
# ExplainedVarOld: -0.0544
# ValFuncLoss: 253
#
#
# ***** Episode 1450, Timesteps 179549, Mean Return = -90.1  *****
# ExplainedVarNew: -0.0713
# ExplainedVarOld: -0.105
# ValFuncLoss: 273
#
#
# ***** Episode 1460, Timesteps 180229, Mean Return = -159.0  *****
# ExplainedVarNew: -0.0598
# ExplainedVarOld: -0.0905
# ValFuncLoss: 211
#
#
# ***** Episode 1470, Timesteps 180881, Mean Return = -146.9  *****
# ExplainedVarNew: -0.0328
# ExplainedVarOld: -0.0638
# ValFuncLoss: 230
#
#
# ***** Episode 1480, Timesteps 182132, Mean Return = -311.6  *****
# ExplainedVarNew: -0.0614
# ExplainedVarOld: -0.0384
# ValFuncLoss: 121
#
#
# ***** Episode 1490, Timesteps 183271, Mean Return = -269.9  *****
# ExplainedVarNew: -0.0274
# ExplainedVarOld: -0.0194
# ValFuncLoss: 165
#
#
# ***** Episode 1500, Timesteps 183994, Mean Return = -162.2  *****
# ExplainedVarNew: -0.0669
# ExplainedVarOld: -0.0738
# ValFuncLoss: 237
#
#
# ***** Episode 1510, Timesteps 184692, Mean Return = -171.3  *****
# ExplainedVarNew: -0.0454
# ExplainedVarOld: -0.0456
# ValFuncLoss: 264
#
#
# ***** Episode 1520, Timesteps 185258, Mean Return = -125.4  *****
# ExplainedVarNew: -0.0213
# ExplainedVarOld: -0.0369
# ValFuncLoss: 249
#
#
# ***** Episode 1530, Timesteps 185786, Mean Return = -114.3  *****
# ExplainedVarNew: -0.0421
# ExplainedVarOld: -0.0349
# ValFuncLoss: 268
#
#
# ***** Episode 1540, Timesteps 186143, Mean Return = -60.1  *****
# ExplainedVarNew: -0.0586
# ExplainedVarOld: -0.0437
# ValFuncLoss: 277
#
#
# ***** Episode 1550, Timesteps 186598, Mean Return = -78.3  *****
# ExplainedVarNew: -0.106
# ExplainedVarOld: -0.119
# ValFuncLoss: 246
#
#
# ***** Episode 1560, Timesteps 187409, Mean Return = -194.1  *****
# ExplainedVarNew: -0.0542
# ExplainedVarOld: -0.0466
# ValFuncLoss: 172
#
#
# ***** Episode 1570, Timesteps 187795, Mean Return = -65.1  *****
# ExplainedVarNew: -0.0389
# ExplainedVarOld: -0.0524
# ValFuncLoss: 246
#
#
# ***** Episode 1580, Timesteps 188388, Mean Return = -128.6  *****
# ExplainedVarNew: -0.0573
# ExplainedVarOld: -0.0808
# ValFuncLoss: 233
#
#
# ***** Episode 1590, Timesteps 189078, Mean Return = -163.5  *****
# ExplainedVarNew: -0.0372
# ExplainedVarOld: -0.0341
# ValFuncLoss: 223
#
#
# ***** Episode 1600, Timesteps 189846, Mean Return = -196.3  *****
# ExplainedVarNew: -0.0371
# ExplainedVarOld: -0.0532
# ValFuncLoss: 261
#
#
# ***** Episode 1610, Timesteps 190700, Mean Return = -197.7  *****
# ExplainedVarNew: -0.0372
# ExplainedVarOld: -0.0887
# ValFuncLoss: 190
#
#
# ***** Episode 1620, Timesteps 191157, Mean Return = -88.9  *****
# ExplainedVarNew: -0.0449
# ExplainedVarOld: -0.0563
# ValFuncLoss: 239
#
#
# ***** Episode 1630, Timesteps 191911, Mean Return = -187.7  *****
# ExplainedVarNew: -0.0382
# ExplainedVarOld: -0.044
# ValFuncLoss: 239
#
#
# ***** Episode 1640, Timesteps 192792, Mean Return = -210.2  *****
# ExplainedVarNew: -0.021
# ExplainedVarOld: -0.0202
# ValFuncLoss: 197
#
#
# ***** Episode 1650, Timesteps 193530, Mean Return = -163.9  *****
# ExplainedVarNew: -0.061
# ExplainedVarOld: -0.0282
# ValFuncLoss: 218
#
#
# ***** Episode 1660, Timesteps 194168, Mean Return = -139.0  *****
# ExplainedVarNew: -0.0286
# ExplainedVarOld: -0.0281
# ValFuncLoss: 201
#
#
# ***** Episode 1670, Timesteps 194798, Mean Return = -143.6  *****
# ExplainedVarNew: -0.0294
# ExplainedVarOld: -0.0915
# ValFuncLoss: 250
#
#
# ***** Episode 1680, Timesteps 195472, Mean Return = -160.7  *****
# ExplainedVarNew: -0.0419
# ExplainedVarOld: -0.0735
# ValFuncLoss: 246
#
#
# ***** Episode 1690, Timesteps 195905, Mean Return = -82.0  *****
# ExplainedVarNew: -0.0367
# ExplainedVarOld: -0.0353
# ValFuncLoss: 276
#
#
# ***** Episode 1700, Timesteps 196459, Mean Return = -126.1  *****
# ExplainedVarNew: -0.0714
# ExplainedVarOld: -0.0609
# ValFuncLoss: 268
#
#
# ***** Episode 1710, Timesteps 197075, Mean Return = -132.9  *****
# ExplainedVarNew: -0.0545
# ExplainedVarOld: -0.0998
# ValFuncLoss: 236
#
#
# ***** Episode 1720, Timesteps 197786, Mean Return = -154.1  *****
# ExplainedVarNew: -0.0368
# ExplainedVarOld: -0.0377
# ValFuncLoss: 184
#
#
# ***** Episode 1730, Timesteps 198557, Mean Return = -183.5  *****
# ExplainedVarNew: -0.0563
# ExplainedVarOld: -0.0618
# ValFuncLoss: 219
#
#
# ***** Episode 1740, Timesteps 199445, Mean Return = -223.4  *****
# ExplainedVarNew: -0.0577
# ExplainedVarOld: -0.0626
# ValFuncLoss: 182
#
#
# ***** Episode 1750, Timesteps 200252, Mean Return = -193.5  *****
# ExplainedVarNew: -0.0369
# ExplainedVarOld: -0.0303
# ValFuncLoss: 171
#
#
# ***** Episode 1760, Timesteps 201003, Mean Return = -154.1  *****
# ExplainedVarNew: -0.0881
# ExplainedVarOld: -0.0832
# ValFuncLoss: 199
#
#
# ***** Episode 1770, Timesteps 201498, Mean Return = -108.3  *****
# ExplainedVarNew: -0.0398
# ExplainedVarOld: -0.0514
# ValFuncLoss: 307
#
#
# ***** Episode 1780, Timesteps 202024, Mean Return = -118.9  *****
# ExplainedVarNew: -0.0598
# ExplainedVarOld: -0.122
# ValFuncLoss: 296
#
#
# ***** Episode 1790, Timesteps 202733, Mean Return = -158.0  *****
# ExplainedVarNew: -0.0616
# ExplainedVarOld: -0.055
# ValFuncLoss: 218
#
#
# ***** Episode 1800, Timesteps 203313, Mean Return = -130.7  *****
# ExplainedVarNew: -0.032
# ExplainedVarOld: -0.0244
# ValFuncLoss: 244
#
#
# ***** Episode 1810, Timesteps 203772, Mean Return = -80.9  *****
# ExplainedVarNew: -0.111
# ExplainedVarOld: -0.152
# ValFuncLoss: 249
#
#
# ***** Episode 1820, Timesteps 204373, Mean Return = -141.1  *****
# ExplainedVarNew: -0.026
# ExplainedVarOld: -0.0294
# ValFuncLoss: 279
#
#
# ***** Episode 1830, Timesteps 205064, Mean Return = -155.5  *****
# ExplainedVarNew: -0.0516
# ExplainedVarOld: -0.0449
# ValFuncLoss: 219
# ***** Episode 1840, Timesteps 205713, Mean Return = -161.7  *****
# ExplainedVarNew: -0.0302
# ExplainedVarOld: -0.0305
# ValFuncLoss: 268
#
#
# ***** Episode 1850, Timesteps 206216, Mean Return = -117.8  *****
# ExplainedVarNew: -0.0547
# ExplainedVarOld: -0.0629
# ValFuncLoss: 307
#
#
# ***** Episode 1860, Timesteps 206582, Mean Return = -64.4  *****
# ExplainedVarNew: -0.0909
# ExplainedVarOld: -0.154
# ValFuncLoss: 306
#
#
# ***** Episode 1870, Timesteps 207029, Mean Return = -96.1  *****
# ExplainedVarNew: -0.0281
# ExplainedVarOld: -0.0336
# ValFuncLoss: 285
#
#
# ***** Episode 1880, Timesteps 207538, Mean Return = -115.2  *****
# ExplainedVarNew: -0.0332
# ExplainedVarOld: -0.0244
# ValFuncLoss: 302
#
#
# ***** Episode 1890, Timesteps 208613, Mean Return = -281.6  *****
# ExplainedVarNew: -0.0351
# ExplainedVarOld: -0.0338
# ValFuncLoss: 163
#
#
# ***** Episode 1900, Timesteps 209163, Mean Return = -115.6  *****
# ExplainedVarNew: -0.0316
# ExplainedVarOld: -0.0348
# ValFuncLoss: 265
#
#
# ***** Episode 1910, Timesteps 209926, Mean Return = -184.2  *****
# ExplainedVarNew: -0.0465
# ExplainedVarOld: -0.101
# ValFuncLoss: 273
#
#
# ***** Episode 1920, Timesteps 210349, Mean Return = -75.3  *****
# ExplainedVarNew: -0.0669
# ExplainedVarOld: -0.231
# ValFuncLoss: 292
#
#
# ***** Episode 1930, Timesteps 210968, Mean Return = -136.4  *****
# ExplainedVarNew: -0.0235
# ExplainedVarOld: -0.0274
# ValFuncLoss: 209
#
#
# ***** Episode 1940, Timesteps 211561, Mean Return = -132.3  *****
# ExplainedVarNew: -0.0421
# ExplainedVarOld: -0.01
# ValFuncLoss: 254
#
#
# ***** Episode 1950, Timesteps 211993, Mean Return = -90.0  *****
# ExplainedVarNew: -0.0822
# ExplainedVarOld: -0.0955
# ValFuncLoss: 308
#
#
# ***** Episode 1960, Timesteps 212636, Mean Return = -154.4  *****
# ExplainedVarNew: -0.0144
# ExplainedVarOld: -0.0163
# ValFuncLoss: 245
#
#
# ***** Episode 1970, Timesteps 213082, Mean Return = -95.0  *****
# ExplainedVarNew: -0.0439
# ExplainedVarOld: -0.0366
# ValFuncLoss: 292
#
#
# ***** Episode 1980, Timesteps 213539, Mean Return = -85.6  *****
# ExplainedVarNew: -0.0299
# ExplainedVarOld: -0.0316
# ValFuncLoss: 277
#
#
# ***** Episode 1990, Timesteps 214168, Mean Return = -153.5  *****
# ExplainedVarNew: -0.00934
# ExplainedVarOld: -0.0105
# ValFuncLoss: 274
#
#
# ***** Episode 2000, Timesteps 214647, Mean Return = -104.5  *****
# ExplainedVarNew: -0.0409
# ExplainedVarOld: -0.0248
# ValFuncLoss: 306

# %% [markdown]
# # Discrete State Space - WPO + GAIL
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
config = tf.ConfigProto(
device_count={'GPU': 1},
intra_op_parallelism_threads=1,
allow_soft_placement=True
)
config.gpu_options.allow_growth = True
sess = tf.InteractiveSession(config=config)
tf.keras.backend.set_session(sess)
discriminator = Discriminator(sess, 10, 0.01, 'D')
sess.run(tf.global_variables_initializer())
tf.reset_default_graph()

env_name = 'Taxi-v3'
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyWass(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
gae_weight = 1
total_eps = 2000
batch_eps = 10
timesteps = 0
logger = Logger(logname=env_name + '_DR-Wass_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        # weight for RL
        lamb = 0.9
        # the randomness of the actions an agent takes can be quantified by the entropy
        entro = entropy(policy.distributions)
        trajectories = run_policy(env, policy, batch_eps, discriminator, lamb, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, gae_weight)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        timesteps += len(observes)
        logger.log({'_Timesteps': timesteps})
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        policy.update(observes, actions, advantages, disc_freqs, env_name, eps)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True)
        
        policy_ob_ac = np.stack((observes, actions),1)
        data = np.load('expert_traj/expert_taxi.npz')
        expert_obs = data['obs'].T[0]
        expert_actions = data['actions'].T[0]
        expert_ob_ac = np.stack((expert_obs, expert_actions),1)
        min_len = min(len(expert_ob_ac), len(policy_ob_ac))
        discriminator.update(np.concatenate([expert_ob_ac[:min_len], policy_ob_ac[:min_len]], axis=0))
logger.close()
sess.close()
# Out:
# /Users/kady/anaconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py:1735: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '
# Value Params -- h1: 10, h2: 7, h3: 5, lr: 0.00378
# ***** Episode 10, Timesteps 2000, Mean Return = -719.0  *****
# ExplainedVarNew: -2.12e-06
# ExplainedVarOld: -3.59e-06
# ValFuncLoss: 1.08e+03
#
#
# ***** Episode 20, Timesteps 4000, Mean Return = -581.8  *****
# ExplainedVarNew: -6.88e-08
# ExplainedVarOld: -1.97e-06
# ValFuncLoss: 550
#
#
# ***** Episode 30, Timesteps 6000, Mean Return = -649.5  *****
# ExplainedVarNew: -1.67e-08
# ExplainedVarOld: -7.88e-08
# ValFuncLoss: 541
#
#
# ***** Episode 40, Timesteps 8000, Mean Return = -663.8  *****
# ExplainedVarNew: -7.23e-09
# ExplainedVarOld: -2.42e-08
# ValFuncLoss: 502
#
#
# ***** Episode 50, Timesteps 10000, Mean Return = -555.6  *****
# ExplainedVarNew: -4.79e-10
# ExplainedVarOld: -9.48e-10
# ValFuncLoss: 250
#
#
# ***** Episode 60, Timesteps 11872, Mean Return = -577.6  *****
# ExplainedVarNew: -7.57e-14
# ExplainedVarOld: -1.09e-13
# ValFuncLoss: 277
#
#
# ***** Episode 70, Timesteps 13620, Mean Return = -430.5  *****
# ExplainedVarNew: -2.35e-13
# ExplainedVarOld: -2.88e-13
# ValFuncLoss: 197
#
#
# ***** Episode 80, Timesteps 15210, Mean Return = -377.3  *****
# ExplainedVarNew: -4.89e-11
# ExplainedVarOld: -5.45e-11
# ValFuncLoss: 214
#
#
# ***** Episode 90, Timesteps 17159, Mean Return = -571.8  *****
# ExplainedVarNew: -4.75e-14
# ExplainedVarOld: -4.24e-14
# ValFuncLoss: 192
#
#
# ***** Episode 100, Timesteps 19159, Mean Return = -595.8  *****
# ExplainedVarNew: -4.96e-13
# ExplainedVarOld: -6.03e-13
# ValFuncLoss: 208
#
#
# ***** Episode 110, Timesteps 20890, Mean Return = -501.7  *****
# ExplainedVarNew: -3.62e-10
# ExplainedVarOld: -4.19e-10
# ValFuncLoss: 181
#
#
# ***** Episode 120, Timesteps 22890, Mean Return = -562.2  *****
# ExplainedVarNew: -4.97e-10
# ExplainedVarOld: -5.56e-10
# ValFuncLoss: 133
#
#
# ***** Episode 130, Timesteps 24725, Mean Return = -533.0  *****
# ExplainedVarNew: -4.42e-14
# ExplainedVarOld: -5.57e-14
# ValFuncLoss: 143
#
#
# ***** Episode 140, Timesteps 26678, Mean Return = -615.4  *****
# ExplainedVarNew: -1.08e-09
# ExplainedVarOld: -1.12e-09
# ValFuncLoss: 137
#
#
# ***** Episode 150, Timesteps 28445, Mean Return = -508.5  *****
# ExplainedVarNew: -1.26e-09
# ExplainedVarOld: -1.19e-09
# ValFuncLoss: 108
#
#
# ***** Episode 160, Timesteps 30170, Mean Return = -425.6  *****
# ExplainedVarNew: -7.28e-12
# ExplainedVarOld: -6.61e-12
# ValFuncLoss: 168
#
#
# ***** Episode 170, Timesteps 31659, Mean Return = -360.4  *****
# ExplainedVarNew: -1.39e-13
# ExplainedVarOld: -1.08e-13
# ValFuncLoss: 152
#
#
# ***** Episode 180, Timesteps 33292, Mean Return = -436.7  *****
# ExplainedVarNew: -3.89e-11
# ExplainedVarOld: -3.71e-11
# ValFuncLoss: 128
#
#
# ***** Episode 190, Timesteps 34607, Mean Return = -328.0  *****
# ExplainedVarNew: -3.6e-14
# ExplainedVarOld: -1.95e-14
# ValFuncLoss: 138
#
#
# ***** Episode 200, Timesteps 36225, Mean Return = -395.5  *****
# ExplainedVarNew: -1.13e-10
# ExplainedVarOld: -1.07e-10
# ValFuncLoss: 97.9
#
#
# ***** Episode 210, Timesteps 37894, Mean Return = -402.0  *****
# ExplainedVarNew: -3.8e-10
# ExplainedVarOld: -3.5e-10
# ValFuncLoss: 152
#
#
# ***** Episode 220, Timesteps 39367, Mean Return = -346.5  *****
# ExplainedVarNew: -7.15e-12
# ExplainedVarOld: -6.74e-12
# ValFuncLoss: 104
#
#
# ***** Episode 230, Timesteps 41031, Mean Return = -371.1  *****
# ExplainedVarNew: -1.09e-13
# ExplainedVarOld: -9.9e-14
# ValFuncLoss: 151
#
#
# ***** Episode 240, Timesteps 42237, Mean Return = -319.3  *****
# ExplainedVarNew: -8.46e-13
# ExplainedVarOld: -8.4e-13
# ValFuncLoss: 183
#
#
# ***** Episode 250, Timesteps 43601, Mean Return = -326.6  *****
# ExplainedVarNew: -1.29e-09
# ExplainedVarOld: -1.24e-09
# ValFuncLoss: 153
#
#
# ***** Episode 260, Timesteps 45293, Mean Return = -368.6  *****
# ExplainedVarNew: -6.59e-12
# ExplainedVarOld: -5.24e-12
# ValFuncLoss: 108
#
#
# ***** Episode 270, Timesteps 46483, Mean Return = -287.1  *****
# ExplainedVarNew: -5.27e-12
# ExplainedVarOld: -4.75e-12
# ValFuncLoss: 166
#
#
# ***** Episode 280, Timesteps 48113, Mean Return = -271.0  *****
# ExplainedVarNew: 3.33e-16
# ExplainedVarOld: -7.55e-15
# ValFuncLoss: 119
#
#
# ***** Episode 290, Timesteps 49622, Mean Return = -242.8  *****
# ExplainedVarNew: -3.48e-13
# ExplainedVarOld: -1.32e-13
# ValFuncLoss: 134
#
#
# ***** Episode 300, Timesteps 50701, Mean Return = -190.3  *****
# ExplainedVarNew: -2.2e-11
# ExplainedVarOld: -1.12e-12
# ValFuncLoss: 106
#
#
# ***** Episode 310, Timesteps 52410, Mean Return = -354.3  *****
# ExplainedVarNew: -1.86e-10
# ExplainedVarOld: -2.18e-10
# ValFuncLoss: 115
#
#
# ***** Episode 320, Timesteps 54094, Mean Return = -346.4  *****
# ExplainedVarNew: -8.16e-12
# ExplainedVarOld: -9.16e-12
# ValFuncLoss: 150
#
#
# ***** Episode 330, Timesteps 55372, Mean Return = -240.0  *****
# ExplainedVarNew: -1.24e-11
# ExplainedVarOld: -1.26e-11
# ValFuncLoss: 143
#
#
# ***** Episode 340, Timesteps 56850, Mean Return = -270.8  *****
# ExplainedVarNew: -1.31e-11
# ExplainedVarOld: -1.34e-11
# ValFuncLoss: 87.2
#
#
# ***** Episode 350, Timesteps 58658, Mean Return = -380.6  *****
# ExplainedVarNew: -1.25e-11
# ExplainedVarOld: -1.41e-11
# ValFuncLoss: 135
#
#
# ***** Episode 360, Timesteps 59625, Mean Return = -196.9  *****
# ExplainedVarNew: -1.28e-11
# ExplainedVarOld: -9.18e-12
# ValFuncLoss: 115
#
#
# ***** Episode 370, Timesteps 61559, Mean Return = -327.2  *****
# ExplainedVarNew: -1.03e-09
# ExplainedVarOld: -8.08e-10
# ValFuncLoss: 80.1
#
#
# ***** Episode 380, Timesteps 62549, Mean Return = -198.1  *****
# ExplainedVarNew: -1.95e-11
# ExplainedVarOld: -1.62e-11
# ValFuncLoss: 180
#
#
# ***** Episode 390, Timesteps 63910, Mean Return = -226.3  *****
# ExplainedVarNew: -2.69e-09
# ExplainedVarOld: -3.11e-09
# ValFuncLoss: 132
#
#
# ***** Episode 400, Timesteps 65312, Mean Return = -205.4  *****
# ExplainedVarNew: -2.19e-10
# ExplainedVarOld: -4.39e-11
# ValFuncLoss: 90.7
#
#
# ***** Episode 410, Timesteps 66589, Mean Return = -233.9  *****
# ExplainedVarNew: -3.51e-09
# ExplainedVarOld: -3.5e-09
# ValFuncLoss: 131
#
#
# ***** Episode 420, Timesteps 68039, Mean Return = -229.8  *****
# ExplainedVarNew: -6.97e-11
# ExplainedVarOld: -1.89e-10
# ValFuncLoss: 78.1
#
#
# ***** Episode 430, Timesteps 68842, Mean Return = -136.9  *****
# ExplainedVarNew: -3.22e-10
# ExplainedVarOld: -2.7e-10
# ValFuncLoss: 147
#
#
# ***** Episode 440, Timesteps 70466, Mean Return = -284.2  *****
# ExplainedVarNew: -3.24e-10
# ExplainedVarOld: -2.58e-10
# ValFuncLoss: 94.7
#
#
# ***** Episode 450, Timesteps 72346, Mean Return = -330.2  *****
# ExplainedVarNew: -2.82e-10
# ExplainedVarOld: -9.78e-10
# ValFuncLoss: 84.7
#
#
# ***** Episode 460, Timesteps 73645, Mean Return = -121.4  *****
# ExplainedVarNew: -4.02e-10
# ExplainedVarOld: -7.73e-11
# ValFuncLoss: 57
#
#
# ***** Episode 470, Timesteps 75356, Mean Return = -286.6  *****
# ExplainedVarNew: -9.05e-06
# ExplainedVarOld: -1.68e-09
# ValFuncLoss: 100
#
#
# ***** Episode 480, Timesteps 76640, Mean Return = -219.0  *****
# ExplainedVarNew: -3.22e-11
# ExplainedVarOld: -3.23e-06
# ValFuncLoss: 107
#
#
# ***** Episode 490, Timesteps 77744, Mean Return = -130.8  *****
# ExplainedVarNew: -9.58e-12
# ExplainedVarOld: -5.31e-12
# ValFuncLoss: 86.3
#
#
# ***** Episode 500, Timesteps 79181, Mean Return = -235.1  *****
# ExplainedVarNew: -1.44e-11
# ExplainedVarOld: -1.22e-11
# ValFuncLoss: 78.3
#
#
# ***** Episode 510, Timesteps 80990, Mean Return = -319.5  *****
# ExplainedVarNew: -1.04e-09
# ExplainedVarOld: -1.42e-08
# ValFuncLoss: 138
#
#
# ***** Episode 520, Timesteps 81857, Mean Return = -112.5  *****
# ExplainedVarNew: -6.36e-11
# ExplainedVarOld: -4.69e-11
# ValFuncLoss: 87.1
#
#
# ***** Episode 530, Timesteps 82783, Mean Return = -171.0  *****
# ExplainedVarNew: -1.16e-09
# ExplainedVarOld: -1.16e-09
# ValFuncLoss: 125
#
#
# ***** Episode 540, Timesteps 83770, Mean Return = -137.2  *****
# ExplainedVarNew: -2.04e-10
# ExplainedVarOld: -1.23e-10
# ValFuncLoss: 122
#
#
# ***** Episode 550, Timesteps 85412, Mean Return = -304.3  *****
# ExplainedVarNew: -1.69e-10
# ExplainedVarOld: -1.39e-10
# ValFuncLoss: 94.5
#
#
# ***** Episode 560, Timesteps 86953, Mean Return = -251.0  *****
# ExplainedVarNew: -1.1e-10
# ExplainedVarOld: -2.39e-10
# ValFuncLoss: 93.6
#
#
# ***** Episode 570, Timesteps 88195, Mean Return = -204.9  *****
# ExplainedVarNew: -3.07e-10
# ExplainedVarOld: -2.78e-10
# ValFuncLoss: 104
#
#
# ***** Episode 580, Timesteps 89642, Mean Return = -263.5  *****
# ExplainedVarNew: -8.98e-11
# ExplainedVarOld: -1.36e-10
# ValFuncLoss: 83.5
#
#
# ***** Episode 590, Timesteps 91091, Mean Return = -198.8  *****
# ExplainedVarNew: -6.97e-11
# ExplainedVarOld: -2.47e-11
# ValFuncLoss: 73
#
#
# ***** Episode 600, Timesteps 92071, Mean Return = -100.8  *****
# ExplainedVarNew: -3.52e-08
# ExplainedVarOld: -2.67e-10
# ValFuncLoss: 66.5
# ***** Episode 610, Timesteps 93341, Mean Return = -218.8  *****
# ExplainedVarNew: -1.13e-08
# ExplainedVarOld: -4.54e-08
# ValFuncLoss: 120
#
#
# ***** Episode 620, Timesteps 94396, Mean Return = -203.1  *****
# ExplainedVarNew: -3.11e-10
# ExplainedVarOld: -2.77e-09
# ValFuncLoss: 144
#
#
# ***** Episode 630, Timesteps 95827, Mean Return = -172.3  *****
# ExplainedVarNew: -3.87e-13
# ExplainedVarOld: -2.46e-13
# ValFuncLoss: 65.6
#
#
# ***** Episode 640, Timesteps 97636, Mean Return = -258.6  *****
# ExplainedVarNew: -2.95e-10
# ExplainedVarOld: -8.37e-11
# ValFuncLoss: 107
#
#
# ***** Episode 650, Timesteps 98936, Mean Return = -154.7  *****
# ExplainedVarNew: -5.84e-11
# ExplainedVarOld: -1.44e-11
# ValFuncLoss: 53.9
#
#
# ***** Episode 660, Timesteps 99999, Mean Return = -99.1  *****
# ExplainedVarNew: -6.66e-10
# ExplainedVarOld: -3.22e-11
# ValFuncLoss: 36
#
#
# ***** Episode 670, Timesteps 100896, Mean Return = -106.9  *****
# ExplainedVarNew: -7.85e-11
# ExplainedVarOld: -7.47e-08
# ValFuncLoss: 79
#
#
# ***** Episode 680, Timesteps 102149, Mean Return = -151.7  *****
# ExplainedVarNew: -4.72e-13
# ExplainedVarOld: -1.16e-10
# ValFuncLoss: 58.8
#
#
# ***** Episode 690, Timesteps 103047, Mean Return = -102.2  *****
# ExplainedVarNew: -2.06e-11
# ExplainedVarOld: -1.8e-11
# ValFuncLoss: 59.4
#
#
# ***** Episode 700, Timesteps 104521, Mean Return = -188.9  *****
# ExplainedVarNew: -1.7e-13
# ExplainedVarOld: -2.8e-13
# ValFuncLoss: 55.5
#
#
# ***** Episode 710, Timesteps 105958, Mean Return = -195.7  *****
# ExplainedVarNew: -6.77e-10
# ExplainedVarOld: -2.22e-09
# ValFuncLoss: 110
#
#
# ***** Episode 720, Timesteps 106832, Mean Return = -65.3  *****
# ExplainedVarNew: -9.75e-14
# ExplainedVarOld: -2.73e-14
# ValFuncLoss: 43
#
#
# ***** Episode 730, Timesteps 108134, Mean Return = -170.3  *****
# ExplainedVarNew: -6.21e-11
# ExplainedVarOld: -5.45e-12
# ValFuncLoss: 92.6
#
#
# ***** Episode 740, Timesteps 109412, Mean Return = -190.2  *****
# ExplainedVarNew: -2.82e-13
# ExplainedVarOld: -4.23e-11
# ValFuncLoss: 137
#
#
# ***** Episode 750, Timesteps 110681, Mean Return = -148.1  *****
# ExplainedVarNew: -2.86e-14
# ExplainedVarOld: -4.26e-14
# ValFuncLoss: 60.8
#
#
# ***** Episode 760, Timesteps 112120, Mean Return = -135.7  *****
# ExplainedVarNew: -2.44e-15
# ExplainedVarOld: -1.11e-15
# ValFuncLoss: 21.6
#
#
# ***** Episode 770, Timesteps 113458, Mean Return = -181.4  *****
# ExplainedVarNew: -2.65e-13
# ExplainedVarOld: -5.02e-13
# ValFuncLoss: 95.4
#
#
# ***** Episode 780, Timesteps 114729, Mean Return = -115.0  *****
# ExplainedVarNew: -4.77e-14
# ExplainedVarOld: -6.51e-14
# ValFuncLoss: 31.4
#
#
# ***** Episode 790, Timesteps 116167, Mean Return = -190.0  *****
# ExplainedVarNew: -8.41e-10
# ExplainedVarOld: -1.46e-09
# ValFuncLoss: 70.6
#
#
# ***** Episode 800, Timesteps 117799, Mean Return = -161.8  *****
# ExplainedVarNew: -9.33e-10
# ExplainedVarOld: -1.95e-09
# ValFuncLoss: 21.8
#
#
# ***** Episode 810, Timesteps 118911, Mean Return = -139.7  *****
# ExplainedVarNew: -1.3e-13
# ExplainedVarOld: -8.64e-14
# ValFuncLoss: 72.8
#
#
# ***** Episode 820, Timesteps 120249, Mean Return = -117.4  *****
# ExplainedVarNew: -5.46e-13
# ExplainedVarOld: -2.42e-13
# ValFuncLoss: 24.8
#
#
# ***** Episode 830, Timesteps 121882, Mean Return = -154.6  *****
# ExplainedVarNew: -4.79e-13
# ExplainedVarOld: -6.95e-13
# ValFuncLoss: 16.1
#
#
# ***** Episode 840, Timesteps 123536, Mean Return = -187.0  *****
# ExplainedVarNew: -5.22e-14
# ExplainedVarOld: -2.08e-13
# ValFuncLoss: 74.5
#
#
# ***** Episode 850, Timesteps 124791, Mean Return = -111.3  *****
# ExplainedVarNew: -4.44e-13
# ExplainedVarOld: -4.93e-13
# ValFuncLoss: 24.4
#
#
# ***** Episode 860, Timesteps 126045, Mean Return = -97.5  *****
# ExplainedVarNew: -1.98e-09
# ExplainedVarOld: -7.93e-12
# ValFuncLoss: 11.6
#
#
# ***** Episode 870, Timesteps 127321, Mean Return = -115.4  *****
# ExplainedVarNew: -2.46e-12
# ExplainedVarOld: -3.71e-11
# ValFuncLoss: 24.4
#
#
# ***** Episode 880, Timesteps 128568, Mean Return = -110.6  *****
# ExplainedVarNew: -2.07e-11
# ExplainedVarOld: -9.35e-11
# ValFuncLoss: 20.5
#
#
# ***** Episode 890, Timesteps 129840, Mean Return = -154.9  *****
# ExplainedVarNew: -8.62e-11
# ExplainedVarOld: -8.82e-10
# ValFuncLoss: 80.9
#
#
# ***** Episode 900, Timesteps 131093, Mean Return = -133.1  *****
# ExplainedVarNew: -1.27e-11
# ExplainedVarOld: -2.31e-11
# ValFuncLoss: 42.5
#
#
# ***** Episode 910, Timesteps 132765, Mean Return = -147.4  *****
# ExplainedVarNew: -8.3e-14
# ExplainedVarOld: -2.84e-14
# ValFuncLoss: 11.1
#
#
# ***** Episode 920, Timesteps 134243, Mean Return = -178.8  *****
# ExplainedVarNew: -1.34e-11
# ExplainedVarOld: -2.75e-11
# ValFuncLoss: 54.4
#
#
# ***** Episode 930, Timesteps 135689, Mean Return = -126.7  *****
# ExplainedVarNew: -6.37e-12
# ExplainedVarOld: -6.83e-12
# ValFuncLoss: 16
#
#
# ***** Episode 940, Timesteps 137323, Mean Return = -153.1  *****
# ExplainedVarNew: -1.11e-15
# ExplainedVarOld: 3.33e-16
# ValFuncLoss: 19.7
#
#
# ***** Episode 950, Timesteps 138575, Mean Return = -99.8  *****
# ExplainedVarNew: -1.62e-13
# ExplainedVarOld: -1.09e-13
# ValFuncLoss: 13.4
#
#
# ***** Episode 960, Timesteps 140018, Mean Return = -128.1  *****
# ExplainedVarNew: -8.88e-16
# ExplainedVarOld: -1.33e-15
# ValFuncLoss: 18.1
#
#
# ***** Episode 970, Timesteps 142018, Mean Return = -180.9  *****
# ExplainedVarNew: -5.18e-10
# ExplainedVarOld: -1.07e-09
# ValFuncLoss: 11.2
#
#
# ***** Episode 980, Timesteps 143268, Mean Return = -102.9  *****
# ExplainedVarNew: -2.14e-13
# ExplainedVarOld: -1.24e-13
# ValFuncLoss: 14.5
#
#
# ***** Episode 990, Timesteps 144001, Mean Return = -84.1  *****
# ExplainedVarNew: 2.22e-16
# ExplainedVarOld: -4.44e-16
# ValFuncLoss: 139
#
#
# ***** Episode 1000, Timesteps 144889, Mean Return = -62.6  *****
# ExplainedVarNew: -4.64e-14
# ExplainedVarOld: -3.82e-14
# ValFuncLoss: 25.3
#
#
# ***** Episode 1010, Timesteps 145961, Mean Return = -81.5  *****
# ExplainedVarNew: -6e-15
# ExplainedVarOld: 4.44e-16
# ValFuncLoss: 16.1
#
#
# ***** Episode 1020, Timesteps 147397, Mean Return = -114.9  *****
# ExplainedVarNew: 3.33e-16
# ExplainedVarOld: 3.33e-16
# ValFuncLoss: 7.86
#
#
# ***** Episode 1030, Timesteps 148835, Mean Return = -114.9  *****
# ExplainedVarNew: -1.39e-12
# ExplainedVarOld: -2.3e-12
# ValFuncLoss: 7.82
#
#
# ***** Episode 1040, Timesteps 150455, Mean Return = -142.3  *****
# ExplainedVarNew: -1.28e-11
# ExplainedVarOld: -2e-11
# ValFuncLoss: 16.1
#
#
# ***** Episode 1050, Timesteps 151513, Mean Return = -79.3  *****
# ExplainedVarNew: -3.55e-11
# ExplainedVarOld: -2.46e-11
# ValFuncLoss: 15.7
#
#
# ***** Episode 1060, Timesteps 153141, Mean Return = -133.1  *****
# ExplainedVarNew: -2.22e-16
# ExplainedVarOld: -1.33e-15
# ValFuncLoss: 6.31
#
#
# ***** Episode 1070, Timesteps 154569, Mean Return = -118.7  *****
# ExplainedVarNew: -2.29e-10
# ExplainedVarOld: -4.13e-10
# ValFuncLoss: 10.7
#
#
# ***** Episode 1080, Timesteps 156222, Mean Return = -170.3  *****
# ExplainedVarNew: -3.7e-13
# ExplainedVarOld: -1.42e-12
# ValFuncLoss: 42.2
#
#
# ***** Episode 1090, Timesteps 157276, Mean Return = -78.4  *****
# ExplainedVarNew: -1.02e-11
# ExplainedVarOld: -8.26e-12
# ValFuncLoss: 17.8
#
#
# ***** Episode 1100, Timesteps 158541, Mean Return = -102.0  *****
# ExplainedVarNew: -1.22e-11
# ExplainedVarOld: -1.9e-12
# ValFuncLoss: 12.1
#
#
# ***** Episode 1110, Timesteps 159424, Mean Return = -64.6  *****
# ExplainedVarNew: -1.34e-11
# ExplainedVarOld: -9.35e-12
# ValFuncLoss: 22.8
#
#
# ***** Episode 1120, Timesteps 161246, Mean Return = -185.4  *****
# ExplainedVarNew: -5.5e-11
# ExplainedVarOld: -9.98e-10
# ValFuncLoss: 44
#
#
# ***** Episode 1130, Timesteps 162525, Mean Return = -101.3  *****
# ExplainedVarNew: -1.53e-14
# ExplainedVarOld: -1.29e-14
# ValFuncLoss: 13.7
#
#
# ***** Episode 1140, Timesteps 163575, Mean Return = -77.7  *****
# ExplainedVarNew: -2.61e-12
# ExplainedVarOld: -8.42e-13
# ValFuncLoss: 15.1
#
#
# ***** Episode 1150, Timesteps 164866, Mean Return = -100.6  *****
# ExplainedVarNew: 6.66e-16
# ExplainedVarOld: 6.66e-16
# ValFuncLoss: 11.4
#
#
# ***** Episode 1160, Timesteps 166121, Mean Return = -99.6  *****
# ExplainedVarNew: -1.78e-15
# ExplainedVarOld: 0
# ValFuncLoss: 12.1
#
#
# ***** Episode 1170, Timesteps 167396, Mean Return = -105.3  *****
# ExplainedVarNew: -2.22e-16
# ExplainedVarOld: -2e-15
# ValFuncLoss: 14.2
#
#
# ***** Episode 1180, Timesteps 168260, Mean Return = -60.8  *****
# ExplainedVarNew: -4.6e-12
# ExplainedVarOld: -3.23e-12
# ValFuncLoss: 21.7
#
#
# ***** Episode 1190, Timesteps 168954, Mean Return = -44.6  *****
# ExplainedVarNew: -4.18e-11
# ExplainedVarOld: -9.16e-12
# ValFuncLoss: 30.4
#
#
# ***** Episode 1200, Timesteps 170399, Mean Return = -117.5  *****
# ExplainedVarNew: -1.33e-15
# ExplainedVarOld: 0
# ValFuncLoss: 9.11
# ***** Episode 1210, Timesteps 172016, Mean Return = -131.0  *****
# ExplainedVarNew: 0
# ExplainedVarOld: -3.55e-15
# ValFuncLoss: 4.92
#
#
# ***** Episode 1220, Timesteps 173450, Mean Return = -113.3  *****
# ExplainedVarNew: -9.69e-12
# ExplainedVarOld: -8.94e-12
# ValFuncLoss: 7.57
#
#
# ***** Episode 1230, Timesteps 175068, Mean Return = -131.4  *****
# ExplainedVarNew: -1.61e-11
# ExplainedVarOld: -1.28e-11
# ValFuncLoss: 4.98
#
#
# ***** Episode 1240, Timesteps 176692, Mean Return = -131.8  *****
# ExplainedVarNew: -1.02e-10
# ExplainedVarOld: -1.04e-10
# ValFuncLoss: 5.34
#
#
# ***** Episode 1250, Timesteps 178136, Mean Return = -143.5  *****
# ExplainedVarNew: -1.32e-10
# ExplainedVarOld: -2.71e-10
# ValFuncLoss: 35.8
#
#
# ***** Episode 1260, Timesteps 179219, Mean Return = -114.2  *****
# ExplainedVarNew: -1.26e-13
# ExplainedVarOld: -2.4e-13
# ValFuncLoss: 63
#
#
# ***** Episode 1270, Timesteps 180473, Mean Return = -97.0  *****
# ExplainedVarNew: 1.11e-16
# ExplainedVarOld: 1.11e-16
# ValFuncLoss: 12.5
#
#
# ***** Episode 1280, Timesteps 181558, Mean Return = -81.2  *****
# ExplainedVarNew: -1.78e-15
# ExplainedVarOld: -4.44e-16
# ValFuncLoss: 15.6
#
#
# ***** Episode 1290, Timesteps 183190, Mean Return = -132.7  *****
# ExplainedVarNew: -4.09e-14
# ExplainedVarOld: -5.95e-14
# ValFuncLoss: 5.45
#
#
# ***** Episode 1300, Timesteps 184068, Mean Return = -61.9  *****
# ExplainedVarNew: -2.22e-16
# ExplainedVarOld: -6.66e-16
# ValFuncLoss: 22.3
#
#
# ***** Episode 1310, Timesteps 185695, Mean Return = -161.2  *****
# ExplainedVarNew: -5.75e-12
# ExplainedVarOld: -2.46e-11
# ValFuncLoss: 33.8
#
#
# ***** Episode 1320, Timesteps 186951, Mean Return = -118.3  *****
# ExplainedVarNew: -1.51e-14
# ExplainedVarOld: -1.91e-14
# ValFuncLoss: 34.5
#
#
# ***** Episode 1330, Timesteps 188392, Mean Return = -113.4  *****
# ExplainedVarNew: -2.22e-15
# ExplainedVarOld: -4.44e-16
# ValFuncLoss: 8.42
#
#
# ***** Episode 1340, Timesteps 189640, Mean Return = -95.9  *****
# ExplainedVarNew: -1.14e-10
# ExplainedVarOld: -5.12e-11
# ValFuncLoss: 11.2
#
#
# ***** Episode 1350, Timesteps 190889, Mean Return = -96.6  *****
# ExplainedVarNew: -2.44e-15
# ExplainedVarOld: -2e-15
# ValFuncLoss: 11.3
#
#
# ***** Episode 1360, Timesteps 192528, Mean Return = -133.3  *****
# ExplainedVarNew: -1.48e-13
# ExplainedVarOld: -5.49e-13
# ValFuncLoss: 5.44
#
#
# ***** Episode 1370, Timesteps 194185, Mean Return = -137.3  *****
# ExplainedVarNew: -6.99e-13
# ExplainedVarOld: -8.48e-13
# ValFuncLoss: 6.48
#
#
# ***** Episode 1380, Timesteps 195078, Mean Return = -64.8  *****
# ExplainedVarNew: -8.85e-13
# ExplainedVarOld: -4.36e-13
# ValFuncLoss: 22.5
#
#
# ***** Episode 1390, Timesteps 196512, Mean Return = -113.4  *****
# ExplainedVarNew: -3.21e-12
# ExplainedVarOld: -1.66e-12
# ValFuncLoss: 7.92
#
#
# ***** Episode 1400, Timesteps 197945, Mean Return = -113.1  *****
# ExplainedVarNew: -1.16e-13
# ExplainedVarOld: -1.55e-13
# ValFuncLoss: 7.74
#
#
# ***** Episode 1410, Timesteps 199389, Mean Return = -115.7  *****
# ExplainedVarNew: 2.22e-16
# ExplainedVarOld: -1.78e-15
# ValFuncLoss: 8.01
#
#
# ***** Episode 1420, Timesteps 200459, Mean Return = -79.5  *****
# ExplainedVarNew: -6.66e-16
# ExplainedVarOld: -2.22e-16
# ValFuncLoss: 15.9
#
#
# ***** Episode 1430, Timesteps 201712, Mean Return = -99.5  *****
# ExplainedVarNew: -9.99e-15
# ExplainedVarOld: -2.22e-15
# ValFuncLoss: 11.3
#
#
# ***** Episode 1440, Timesteps 203160, Mean Return = -115.0  *****
# ExplainedVarNew: -3.32e-13
# ExplainedVarOld: -2.67e-12
# ValFuncLoss: 8.09
#
#
# ***** Episode 1450, Timesteps 204779, Mean Return = -131.3  *****
# ExplainedVarNew: -4.03e-11
# ExplainedVarOld: -1.09e-10
# ValFuncLoss: 5.03
#
#
# ***** Episode 1460, Timesteps 206043, Mean Return = -97.6  *****
# ExplainedVarNew: -1.11e-13
# ExplainedVarOld: -1.4e-13
# ValFuncLoss: 11.4
#
#
# ***** Episode 1470, Timesteps 207318, Mean Return = -128.0  *****
# ExplainedVarNew: -1.11e-15
# ExplainedVarOld: 8.88e-16
# ValFuncLoss: 42.8
#
#
# ***** Episode 1480, Timesteps 208570, Mean Return = -96.0  *****
# ExplainedVarNew: -2.22e-16
# ExplainedVarOld: -2.22e-16
# ValFuncLoss: 12.4
#
#
# ***** Episode 1490, Timesteps 209635, Mean Return = -79.0  *****
# ExplainedVarNew: -1.35e-14
# ExplainedVarOld: -3.33e-15
# ValFuncLoss: 15.8
#
#
# ***** Episode 1500, Timesteps 211256, Mean Return = -131.4  *****
# ExplainedVarNew: -1.08e-12
# ExplainedVarOld: -1.78e-12
# ValFuncLoss: 5.21
#
#
# ***** Episode 1510, Timesteps 212501, Mean Return = -96.7  *****
# ExplainedVarNew: -5.62e-13
# ExplainedVarOld: -5.6e-13
# ValFuncLoss: 11.2
#
#
# ***** Episode 1520, Timesteps 213954, Mean Return = -115.8  *****
# ExplainedVarNew: -7.55e-15
# ExplainedVarOld: -1.78e-15
# ValFuncLoss: 8.05
#
#
# ***** Episode 1530, Timesteps 214840, Mean Return = -62.5  *****
# ExplainedVarNew: -8.15e-14
# ExplainedVarOld: -2.82e-14
# ValFuncLoss: 21.8
#
#
# ***** Episode 1540, Timesteps 216091, Mean Return = -96.4  *****
# ExplainedVarNew: -6.64e-14
# ExplainedVarOld: -2.44e-15
# ValFuncLoss: 11.4
#
#
# ***** Episode 1550, Timesteps 217347, Mean Return = -96.5  *****
# ExplainedVarNew: -4.64e-12
# ExplainedVarOld: -2.37e-11
# ValFuncLoss: 11.3
#
#
# ***** Episode 1560, Timesteps 218784, Mean Return = -113.7  *****
# ExplainedVarNew: -5.26e-13
# ExplainedVarOld: -5.27e-13
# ValFuncLoss: 7.76
#
#
# ***** Episode 1570, Timesteps 219482, Mean Return = -44.9  *****
# ExplainedVarNew: -2.89e-15
# ExplainedVarOld: -8.66e-15
# ValFuncLoss: 31.1
#
#
# ***** Episode 1580, Timesteps 220726, Mean Return = -96.2  *****
# ExplainedVarNew: -2.74e-12
# ExplainedVarOld: -1.4e-12
# ValFuncLoss: 11.3
#
#
# ***** Episode 1590, Timesteps 221785, Mean Return = -79.2  *****
# ExplainedVarNew: -2.2e-13
# ExplainedVarOld: -1.84e-13
# ValFuncLoss: 15.8
#
#
# ***** Episode 1600, Timesteps 223227, Mean Return = -115.8  *****
# ExplainedVarNew: -5.39e-13
# ExplainedVarOld: -3.22e-13
# ValFuncLoss: 7.94
#
#
# ***** Episode 1610, Timesteps 224679, Mean Return = -171.4  *****
# ExplainedVarNew: -6.66e-16
# ExplainedVarOld: -6.66e-16
# ValFuncLoss: 66
#
#
# ***** Episode 1620, Timesteps 226119, Mean Return = -113.9  *****
# ExplainedVarNew: -1.55e-15
# ExplainedVarOld: -1.78e-15
# ValFuncLoss: 11.8
#
#
# ***** Episode 1630, Timesteps 227371, Mean Return = -96.3  *****
# ExplainedVarNew: -9.77e-15
# ExplainedVarOld: -1.33e-15
# ValFuncLoss: 11.3
#
#
# ***** Episode 1640, Timesteps 228622, Mean Return = -97.2  *****
# ExplainedVarNew: -1.11e-15
# ExplainedVarOld: -2.22e-16
# ValFuncLoss: 11.4
#
#
# ***** Episode 1650, Timesteps 230622, Mean Return = -166.6  *****
# ExplainedVarNew: -1.33e-15
# ExplainedVarOld: -1.2e-14
# ValFuncLoss: 1.4
#
#
# ***** Episode 1660, Timesteps 232248, Mean Return = -132.0  *****
# ExplainedVarNew: -4.66e-15
# ExplainedVarOld: -1.78e-15
# ValFuncLoss: 5.33
#
#
# ***** Episode 1670, Timesteps 233507, Mean Return = -97.6  *****
# ExplainedVarNew: -1.33e-15
# ExplainedVarOld: -2.22e-15
# ValFuncLoss: 11.5
#
#
# ***** Episode 1680, Timesteps 234748, Mean Return = -96.1  *****
# ExplainedVarNew: -2.28e-12
# ExplainedVarOld: -3.52e-13
# ValFuncLoss: 10.8
#
#
# ***** Episode 1690, Timesteps 236560, Mean Return = -149.0  *****
# ExplainedVarNew: -1.11e-14
# ExplainedVarOld: -8.23e-12
# ValFuncLoss: 3.13
#
#
# ***** Episode 1700, Timesteps 237999, Mean Return = -114.1  *****
# ExplainedVarNew: -1.22e-14
# ExplainedVarOld: -3.15e-14
# ValFuncLoss: 7.75
#
#
# ***** Episode 1710, Timesteps 239250, Mean Return = -96.4  *****
# ExplainedVarNew: -4.55e-14
# ExplainedVarOld: -2.86e-14
# ValFuncLoss: 11.2
#
#
# ***** Episode 1720, Timesteps 240683, Mean Return = -113.7  *****
# ExplainedVarNew: -2.8e-14
# ExplainedVarOld: -3.02e-14
# ValFuncLoss: 7.74
#
#
# ***** Episode 1730, Timesteps 241932, Mean Return = -96.5  *****
# ExplainedVarNew: -6.22e-15
# ExplainedVarOld: -8.88e-16
# ValFuncLoss: 11.3
#
#
# ***** Episode 1740, Timesteps 243182, Mean Return = -96.7  *****
# ExplainedVarNew: -8.88e-16
# ExplainedVarOld: -1.13e-14
# ValFuncLoss: 11.2
#
#
# ***** Episode 1750, Timesteps 244244, Mean Return = -79.2  *****
# ExplainedVarNew: -2.13e-12
# ExplainedVarOld: -6.61e-13
# ValFuncLoss: 15.7
#
#
# ***** Episode 1760, Timesteps 245497, Mean Return = -96.8  *****
# ExplainedVarNew: -1.64e-10
# ExplainedVarOld: -3.7e-12
# ValFuncLoss: 11.4
#
#
# ***** Episode 1770, Timesteps 246755, Mean Return = -104.6  *****
# ExplainedVarNew: -9.02e-13
# ExplainedVarOld: -3.59e-12
# ValFuncLoss: 21.3
#
#
# ***** Episode 1780, Timesteps 248198, Mean Return = -114.6  *****
# ExplainedVarNew: -2.69e-11
# ExplainedVarOld: -9.04e-12
# ValFuncLoss: 8
#
#
# ***** Episode 1790, Timesteps 249447, Mean Return = -96.4  *****
# ExplainedVarNew: -5.48e-14
# ExplainedVarOld: -2.68e-11
# ValFuncLoss: 11.3
# ***** Episode 1800, Timesteps 250696, Mean Return = -96.3  *****
# ExplainedVarNew: -1.15e-14
# ExplainedVarOld: -1.24e-12
# ValFuncLoss: 11.2
#
#
# ***** Episode 1810, Timesteps 251952, Mean Return = -97.1  *****
# ExplainedVarNew: 6.66e-16
# ExplainedVarOld: -2.22e-16
# ValFuncLoss: 11.3
#
#
# ***** Episode 1820, Timesteps 253395, Mean Return = -114.5  *****
# ExplainedVarNew: -8.88e-16
# ExplainedVarOld: -1.55e-15
# ValFuncLoss: 8.02
#
#
# ***** Episode 1830, Timesteps 254838, Mean Return = -114.7  *****
# ExplainedVarNew: -2e-15
# ExplainedVarOld: -4.44e-16
# ValFuncLoss: 8.07
#
#
# ***** Episode 1840, Timesteps 256097, Mean Return = -97.5  *****
# ExplainedVarNew: -4.44e-16
# ExplainedVarOld: -1.11e-15
# ValFuncLoss: 11.5
#
#
# ***** Episode 1850, Timesteps 256786, Mean Return = -43.4  *****
# ExplainedVarNew: -3.11e-15
# ExplainedVarOld: -2.2e-13
# ValFuncLoss: 30.8
#
#
# ***** Episode 1860, Timesteps 258211, Mean Return = -112.9  *****
# ExplainedVarNew: -5.26e-13
# ExplainedVarOld: -2.31e-12
# ValFuncLoss: 7.66
#
#
# ***** Episode 1870, Timesteps 259648, Mean Return = -113.1  *****
# ExplainedVarNew: -8.31e-13
# ExplainedVarOld: -2.33e-12
# ValFuncLoss: 7.86
#
#
# ***** Episode 1880, Timesteps 260911, Mean Return = -97.2  *****
# ExplainedVarNew: -9.47e-13
# ExplainedVarOld: -9.05e-13
# ValFuncLoss: 11.5
#
#
# ***** Episode 1890, Timesteps 261970, Mean Return = -78.8  *****
# ExplainedVarNew: -1.33e-15
# ExplainedVarOld: -1.33e-15
# ValFuncLoss: 15.7
#
#
# ***** Episode 1900, Timesteps 263030, Mean Return = -79.3  *****
# ExplainedVarNew: 4.44e-16
# ExplainedVarOld: 4.44e-16
# ValFuncLoss: 15.5
#
#
# ***** Episode 1910, Timesteps 265030, Mean Return = -168.5  *****
# ExplainedVarNew: -2.44e-15
# ExplainedVarOld: -2.44e-15
# ValFuncLoss: 1.48
#
#
# ***** Episode 1920, Timesteps 266089, Mean Return = -79.1  *****
# ExplainedVarNew: -2.89e-15
# ExplainedVarOld: 0
# ValFuncLoss: 16
#
#
# ***** Episode 1930, Timesteps 267339, Mean Return = -96.5  *****
# ExplainedVarNew: -5.52e-13
# ExplainedVarOld: -4.02e-13
# ValFuncLoss: 11.1
#
#
# ***** Episode 1940, Timesteps 268769, Mean Return = -112.9  *****
# ExplainedVarNew: -2.22e-16
# ExplainedVarOld: -2.22e-15
# ValFuncLoss: 7.6
#
#
# ***** Episode 1950, Timesteps 269848, Mean Return = -79.9  *****
# ExplainedVarNew: -4.44e-16
# ExplainedVarOld: -4.44e-16
# ValFuncLoss: 15.5
#
#
# ***** Episode 1960, Timesteps 271099, Mean Return = -96.3  *****
# ExplainedVarNew: -8.88e-16
# ExplainedVarOld: -1.33e-15
# ValFuncLoss: 11.3
#
#
# ***** Episode 1970, Timesteps 272344, Mean Return = -96.1  *****
# ExplainedVarNew: 4.44e-16
# ExplainedVarOld: -8.88e-16
# ValFuncLoss: 11
#
#
# ***** Episode 1980, Timesteps 273409, Mean Return = -79.8  *****
# ExplainedVarNew: -1.11e-15
# ExplainedVarOld: 2.22e-16
# ValFuncLoss: 15.5
#
#
# ***** Episode 1990, Timesteps 275038, Mean Return = -132.8  *****
# ExplainedVarNew: -2.22e-16
# ExplainedVarOld: -2.22e-15
# ValFuncLoss: 5.45
#
#
# ***** Episode 2000, Timesteps 276296, Mean Return = -97.6  *****
# ExplainedVarNew: -4.44e-16
# ExplainedVarOld: -4.44e-16
# ValFuncLoss: 11.5

# %% [markdown]
# # Discrete State Space - KL PO
# ### 'Taxi-v3', 'Roulette-v0', 'NChain-v0', 'FrozenLake-v0', 'CliffWalking-v0', 'FrozenLake8x8-v0'

# %%
env_name = 'Taxi-v3'
env = gym.make(env_name)
sta_num = env.observation_space.n
act_num = env.action_space.n
policy = DRPolicyKL(sta_num, act_num)
val_func = NNValueFunction(1, 10)
gamma = 0.9
lam = 1
total_eps = 1000
batch_eps = 60
logger = Logger(logname=env_name + '_DR-KL_Batch=' + str(batch_eps), now=datetime.utcnow().strftime("%b-%d_%H:%M:%S"))


eps = 0
while eps < total_eps:
        trajectories = run_policy(env, policy, batch_eps, logger)
        eps += len(trajectories)
        # add estimated values to episodes
        add_value(trajectories, val_func)  
        # calculated discounted sum of Rs
        add_disc_sum_rew(trajectories, gamma, logger)  
        # calculate advantage
        add_gae(trajectories, gamma, lam)  
        # concatenate all episodes into single NumPy arrays
        observes, actions, advantages, disc_sum_rew = build_train_set(trajectories)
        log_batch_stats(observes, actions, advantages, disc_sum_rew, eps, logger)
        disc_freqs = find_disc_freqs(trajectories, sta_num, gamma)
        policy.update(observes, actions, advantages, disc_freqs, env_name, eps)
        val_func.fit(observes, disc_sum_rew, logger)
        # write logger results to file and stdout
        logger.write(display=True) 
logger.close()

# %% [markdown]
# ## Generate Expert Trajectories

# %%
from stable_baselines import PPO2
from stable_baselines.gail import generate_expert_traj

# Generate expert trajectories (train expert)
model = PPO2('MlpPolicy', 'Taxi-v3', verbose=1)
# Train for 60000 timesteps and record 10 trajectories
# all the data will be saved in 'expert_pendulum.npz' file
generate_expert_traj(model, 'expert_taxi', n_timesteps=600000, n_episodes=10)
